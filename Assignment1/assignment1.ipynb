# %%
import pickle
import pandas as pd
import numpy as np
from numpy import matlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1 Training a multi-linear classifier

# %%
def load_data(directory):
    
    # load data as a normalized way
    
    C=10  #number of classes
    X = LoadBatch(directory)[b'data'].transpose()
    # normalize the raw input data
    X_mean = X.mean(axis=1).reshape(-1,1)
    X_std = X.std(axis=1).reshape(-1,1)
    X = (X-X_mean)/X_std
    y = np.array(LoadBatch(directory)[b'labels'])
    #one-hot representation of the label for each image
    Y = np.eye(C, dtype=int)[y].transpose()
    return X, Y, y

def LoadBatch(filename):
    """ Copied from the dataset website """
    with open(filename, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# #### Read in and store the training, validation and test data.

# %%
Xtr, Ytr, ytr = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_1")
Xva, Yva, yva = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_2")
Xte, Yte, yte = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/test_batch")

# %%
print(Xtr.shape[1])
print(Ytr.shape[0], Ytr.shape[1])
# Out:
# 10000
# 10 10000

# %% [markdown]
# ## Define some functions

# %%
def ComputeGradsNumSlow( X, Y, P, W, b, h,lamda):
        
        # centered difference formula 
        
        k = W.shape[0]
        d = X.shape[0]

        grad_W = np.zeros(W.shape)
        grad_b = np.zeros((k, 1))   

        for i in range(len(b)):
            b_try = np.array(b)
            b_try[i] -= h
            c1 = compute_cost(X, Y, W, b_try,lamda)

            b_try = np.array(b)
            b_try[i] += h
            c2 = compute_cost(X, Y, W, b_try,lamda)

            grad_b[i] = (c2-c1) / (2*h)

        for i in range(W.shape[0]):
            for j in range(W.shape[1]):
                W_try = np.array(W)
                W_try[i,j] -= h
                c1 = compute_cost(X, Y, W_try, b,lamda)

                W_try = np.array(W)
                W_try[i,j] += h
                c2 = compute_cost(X, Y, W_try, b, lamda)

                grad_W[i,j] = (c2-c1) / (2*h)

        return [grad_W, grad_b]
    
def load_label_names(self):
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
        

def ini_parameters(X, Y):
    
    #generate w and b according to the shape of inputs   
    std=np.sqrt(2/X.shape[0]) 
    #std=0.01
    np.random.seed(100)
    W = std*np.random.randn(Y.shape[0],X.shape[0])+0
    np.random.seed(100)
    b = std*np.random.randn(Y.shape[0],1)+0
    return W, b
    
    
def evaluate_classifier(X, W, b):
        
    # Write a function that evaluates the network function                                            
    
        assert(X.shape[0]== W.shape[1])
        s=np.dot(W, X)+b
        return  softmax(s)
    
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=0)    


def compute_cost(X, Y, y, W, b, lamda,svm=False):
        
    # calculate full loss function
    if svm ==False:
        L = cross_entropy(X, Y, W, b)+np.sum(W**2)*lamda
    elif svm==True:
        L = svm_loss(X, y, W, b)+np.sum(W**2)*lamda
    return L
        
    
def cross_entropy(X, Y, W, b):
        
      #define cross entropy loss
    
    cross_entropy_loss = np.dot(Y.transpose(), evaluate_classifier(X,W,b))               
    cross_entropy_loss = np.diag(cross_entropy_loss)
    cross_entropy_loss = -np.log(cross_entropy_loss)
    loss = np.sum(cross_entropy_loss)/ Y.shape[1]
    return loss

def svm_loss(X, y, W, b):
    
    #define svm loss
    
    assert(X.shape[0]== W.shape[1])
    s=np.dot(W, X)+b
    l=np.zeros(s.shape)
    for i in range(s.shape[0]):
        for j in range(s.shape[1]):
            l[i][j]= max(0, s[i][j]-s[y[j]][j]+1)
    loss=np.sum(l)/ X.shape[1]
    return loss   
   
    
def compute_accuracy(X, y, W, b):
        
  #compute the accuracy of the network prediction

    k = np.argmax(evaluate_classifier(X,W,b), axis=0)
    acc=0
    for i in range(X.shape[1]):
        if k[i]==y[i]:
            acc+=1
    acc=acc/X.shape[1]
    return acc
        
    
def compute_gradient(X, Y, W, b,lamda,svm=False):
         
    #evaluate the gradients of the cost function for a mini-batch
    if svm==False:
        P=evaluate_classifier(X, W, b)
    
        g=P-Y
        assert(X.shape[1]== g.shape[1])
        grad_b = np.dot(g,np.ones((X.shape[1],1)))/X.shape[1]
        grad_w = np.dot(g, X.T)/X.shape[1]+2*lamda*W
        return grad_w, grad_b
    else:
        n = X.shape[1]
        d = X.shape[0]
        K = Y.shape[0]
        gradW = np.zeros((K, d))
        gradb = np.zeros((K, 1))

        for i in range(n):
            x = X[:, i]
            y_int = np.where(Y[:, [i]].T[0] == 1)[0][0]
            s = np.dot(W, X[:, [i]]) + b
            for j in range(K):
                if j != y_int:
                    if max(0, s[j] - s[y_int] + 1) != 0:
                        gradW[j] += x
                        gradW[y_int] += -x
                        gradb[j, 0] += 1
                        gradb[y_int, 0] += -1

        gradW /= n
        gradW += lamda * W
        gradb /= n
        return gradW, gradb


def ComputeGradsNum(X, Y, y, W, b, h, lamda):
        
    # finite difference method
    
        k = W.shape[0]
        d = X.shape[0]

        grad_W = np.zeros(W.shape);
        grad_b = np.zeros((k, 1));

        c = compute_cost(X, Y, y, W, b,lamda,svm=False);
        
        
        for i in range(b.shape[0]):
            
            b_try1 = np.array(b)
            b_try2 = np.array(b)
            b_try1[i][0] += h
            b_try2[i][0] -= h
        
            
            c1 = compute_cost(X, Y,y, W, b_try1,lamda,svm=False)
            c2 = compute_cost(X, Y, y,W, b_try2,lamda,svm=False)
            grad_b[i] = (c1-c2) / (2*h)
            
            
        for i in range(W.shape[0]):
            for j in range(W.shape[1]):
                W_try = np.array(W)
                W_try[i,j] += h
                c2 = compute_cost(X, Y,y, W_try, b,lamda,svm=False)
                grad_W[i,j] = (c2-c) / h

        return [grad_W, grad_b]
    
def montage(W):
	""" Display the image for each label in W """
	import matplotlib.pyplot as plt
	fig, ax = plt.subplots(2,5)
	for i in range(2):
		for j in range(5):
			im  = W[5*i+j,:].reshape(32,32,3, order='F')
			sim = (im-np.min(im[:]))/(np.max(im[:])-np.min(im[:]))
			sim = sim.transpose(1,0,2)
			ax[i][j].imshow(sim, interpolation='nearest')
			ax[i][j].set_title("y="+str(5*i+j))
			ax[i][j].axis('off')
	plt.show()

# %%
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    #remember to transpose inputs when using this
    #assert inputs.shape[0] == targets.shape[0]
    if shuffle:
        indices = np.arange(inputs.shape[0])
        np.random.shuffle(indices)
    for start_idx in range(0, inputs.shape[0] - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        return inputs[excerpt], targets[excerpt]

# %% [markdown]
# ## Check gradients

# %%
xmini, ymini=iterate_minibatches(Xtr.T, ytr, 100)
xmini=xmini.T
Ymini = np.eye(10, dtype=int)[ymini].transpose()
W, b= ini_parameters(xmini, Ymini)
P=evaluate_classifier(xmini, W, b)
gnw, gnb=ComputeGradsNum(X=xmini, Y= Ymini,y=ymini,  W=W, b=b, h=0.001,lamda=0)
gaw, gab=compute_gradient(X=xmini, Y= Ymini,  W=W,b=b,lamda=0,svm=False)
err=np.abs(gaw-gnw)/(np.abs(gaw)+np.abs(gnw))
print(err)
# Out:
# [[0.00121301 0.00386175 0.00302505 ... 0.00202511 0.00160751 0.00074994]
#  [0.00043719 0.00050799 0.00037732 ... 0.0021566  0.00093341 0.00079176]
#  [0.00080395 0.00059602 0.00139554 ... 0.00055949 0.00051325 0.00047505]
#  ...
#  [0.00021944 0.00023458 0.0002398  ... 0.00039616 0.00056296 0.00049396]
#  [0.0007845  0.0005969  0.00055309 ... 0.00040166 0.00043315 0.00056944]
#  [0.00025196 0.00030337 0.00033024 ... 0.00028696 0.00031394 0.00030471]]

# %% [markdown]
# ## Build the one layer classifier

# %%
class one_layer_classifier():
    
    def __init__(self, lamda=0, n_epochs=40, n_batch=100, eta=0.1, decay_factor=1,svm=False):
    
        self.W, self.b = ini_parameters(Xtr, Ytr)
        self.P = 0
        self.lamda=lamda
        self.n_batch=n_batch
        self.n_epochs=n_epochs
        self.eta = eta
        self.decay_factor=decay_factor
        self.svm=svm
        self.best_b=0
        self.best_w=0
    
    def fit(self,Xtr, Ytr, ytr, Xva, Yva, yva):
        
        trainingloss=[]
        validationloss=[]
        trainingaccuracy=[]
        validationaccuracy=[]
        
        for i in range(self.n_epochs):
            best_model=0
            best_acc=0
            l1=compute_cost(Xtr, Ytr, ytr, self.W, self.b, self.lamda,self.svm)
            trainingloss.append(l1)
            acc=compute_accuracy(Xtr, ytr, self.W, self.b)
            trainingaccuracy.append(acc)
            print("the",format(i),"epoch for training data,"," the loss is", l1, "the accuracy is ",acc)
            l2=compute_cost(Xva, Yva, yva, self.W, self.b, self.lamda,self.svm)
            validationloss.append(l2)
            acc=compute_accuracy(Xva, yva, self.W, self.b)
            if acc>best_acc:
                best_model=i
                best_acc=acc
                self.best_w=self.W
                self.best_b=self.b
            validationaccuracy.append(acc)
            print("the",format(i),"epoch for validation data,"," the loss is", l2, "the accuracy is ",acc)
            
            Xtr, ytr=iterate_minibatches(Xtr.T, ytr, 10000, shuffle=True)
            Xtr=Xtr.T
            Ytr = np.eye(10, dtype=int)[ytr].transpose()
            #print(Xtr.shape,Ytr.shape,ytr.shape)
            
            for i in range(Xtr.shape[1]//self.n_batch):
                
                x_mini_batch = Xtr.T[i*self.n_batch:(i+1)*self.n_batch]
                Y_mini_batch = Ytr.T[i*self.n_batch:(i+1)*self.n_batch]
                
                
                
                gradw, gradb = compute_gradient(x_mini_batch.T, Y_mini_batch.T, self.W, self.b, self.lamda,self.svm)
                self.W-= gradw*self.eta
                self.b-= gradb*self.eta
                
            self.eta = self.eta * self.decay_factor
            
        x = range(1,self.n_epochs+1)    
        plt.plot(x, trainingloss,  label = "training loss" )
        plt.plot(x, validationloss, label = "validation loss" )
        plt.xlabel("epoch")
        plt.ylabel("loss")
        plt.legend()
        plt.title('training and validation loss') 
        plt.show()
        
        x = range(1,self.n_epochs+1)    
        plt.plot(x, trainingaccuracy,  label = "training accuracy" )
        plt.plot(x, validationaccuracy, label = "validation accuracy" )
        plt.xlabel("epoch")
        plt.ylabel("accuracy")
        plt.legend()
        plt.title('training and validation accuracy') 
        plt.show()
        
        #print(self.W,self.b)
        montage(self.W)  
        print("the last model is in",best_model, "the accuracy is",best_acc)
        
    def predict(self, Xte, Yte, yte):
        
        l=compute_cost(Xte, Yte,yte, self.best_w, self.best_b, self.lamda,self.svm)
        acc=compute_accuracy(Xte, yte, self.best_w, self.best_b)
        print("the loss is", l, "the accuracy is ",acc)

# %%
c = one_layer_classifier(lamda=0, n_epochs=40, n_batch=100, eta=0.1, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 2.9730223993079044 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 2.9494820921155 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 6.098131288646469 the accuracy is  0.27
# the 1 epoch for validation data,  the loss is 6.486042236403405 the accuracy is  0.2425
# the 2 epoch for training data,  the loss is 8.387594572290682 the accuracy is  0.2799
# the 2 epoch for validation data,  the loss is 8.976124644676613 the accuracy is  0.2501
# the 3 epoch for training data,  the loss is 4.5693314685649185 the accuracy is  0.3296
# the 3 epoch for validation data,  the loss is 5.401796497909825 the accuracy is  0.2769
# the 4 epoch for training data,  the loss is 5.310872795617316 the accuracy is  0.3509
# the 4 epoch for validation data,  the loss is 6.372605217040227 the accuracy is  0.2853
# the 5 epoch for training data,  the loss is 6.069547354782255 the accuracy is  0.3374
# the 5 epoch for validation data,  the loss is 7.186244077207177 the accuracy is  0.276
# the 6 epoch for training data,  the loss is 4.527520530634305 the accuracy is  0.3787
# the 6 epoch for validation data,  the loss is 5.695828498389545 the accuracy is  0.3007
# the 7 epoch for training data,  the loss is 6.219361333247589 the accuracy is  0.3115
# the 7 epoch for validation data,  the loss is 7.428025585056563 the accuracy is  0.2452
# the 8 epoch for training data,  the loss is 5.133166204623468 the accuracy is  0.3504
# the 8 epoch for validation data,  the loss is 6.5079977853357915 the accuracy is  0.2772
# the 9 epoch for training data,  the loss is 5.9576222588376755 the accuracy is  0.3516
# the 9 epoch for validation data,  the loss is 7.392371931185624 the accuracy is  0.2802
# the 10 epoch for training data,  the loss is 5.3663710100016875 the accuracy is  0.3615
# the 10 epoch for validation data,  the loss is 6.726222619297527 the accuracy is  0.2691
# the 11 epoch for training data,  the loss is 4.463165528851302 the accuracy is  0.3822
# the 11 epoch for validation data,  the loss is 5.974146209872783 the accuracy is  0.2835
# the 12 epoch for training data,  the loss is 5.127045713218431 the accuracy is  0.357
# the 12 epoch for validation data,  the loss is 6.759693196718789 the accuracy is  0.2703
# the 13 epoch for training data,  the loss is 5.386018803927868 the accuracy is  0.3648
# the 13 epoch for validation data,  the loss is 7.061590623701499 the accuracy is  0.2737
# the 14 epoch for training data,  the loss is 3.0852075277149766 the accuracy is  0.424
# the 14 epoch for validation data,  the loss is 4.6629757110195085 the accuracy is  0.2923
# the 15 epoch for training data,  the loss is 4.951695214649972 the accuracy is  0.4029
# the 15 epoch for validation data,  the loss is 6.809564923230937 the accuracy is  0.2879
# the 16 epoch for training data,  the loss is 4.55193253647633 the accuracy is  0.39
# the 16 epoch for validation data,  the loss is 6.314271437041063 the accuracy is  0.2754
# the 17 epoch for training data,  the loss is 5.11896787142336 the accuracy is  0.3777
# the 17 epoch for validation data,  the loss is 7.001941312072802 the accuracy is  0.2785
# the 18 epoch for training data,  the loss is 5.910737979193412 the accuracy is  0.4076
# the 18 epoch for validation data,  the loss is 7.842264585380272 the accuracy is  0.3083
# the 19 epoch for training data,  the loss is 4.254595261773593 the accuracy is  0.4032
# the 19 epoch for validation data,  the loss is 6.120606784649564 the accuracy is  0.2776
# the 20 epoch for training data,  the loss is 4.76476947505187 the accuracy is  0.4096
# the 20 epoch for validation data,  the loss is 6.749509420297854 the accuracy is  0.2921
# the 21 epoch for training data,  the loss is 4.207284417798283 the accuracy is  0.4221
# the 21 epoch for validation data,  the loss is 6.3002059990618795 the accuracy is  0.2923
# the 22 epoch for training data,  the loss is 5.950397628699677 the accuracy is  0.3664
# the 22 epoch for validation data,  the loss is 8.017651527654683 the accuracy is  0.2719
# the 23 epoch for training data,  the loss is 5.106265720737281 the accuracy is  0.3971
# the 23 epoch for validation data,  the loss is 7.091872504686372 the accuracy is  0.2806
# the 24 epoch for training data,  the loss is 4.502640793705939 the accuracy is  0.4163
# the 24 epoch for validation data,  the loss is 6.677241309535218 the accuracy is  0.2922
# the 25 epoch for training data,  the loss is 3.801020595445794 the accuracy is  0.4385
# the 25 epoch for validation data,  the loss is 5.990222458896881 the accuracy is  0.2966
# the 26 epoch for training data,  the loss is 4.005115880221204 the accuracy is  0.445
# the 26 epoch for validation data,  the loss is 6.1187165048326975 the accuracy is  0.3018
# the 27 epoch for training data,  the loss is 3.620781034167255 the accuracy is  0.4499
# the 27 epoch for validation data,  the loss is 5.717098912044153 the accuracy is  0.292
# the 28 epoch for training data,  the loss is 5.648950995921383 the accuracy is  0.4051
# the 28 epoch for validation data,  the loss is 7.866037454328162 the accuracy is  0.2908
# the 29 epoch for training data,  the loss is 6.264334031875203 the accuracy is  0.3575
# the 29 epoch for validation data,  the loss is 8.491085786095299 the accuracy is  0.2547
# the 30 epoch for training data,  the loss is 3.720979401617007 the accuracy is  0.4458
# the 30 epoch for validation data,  the loss is 6.006878306002076 the accuracy is  0.3026
# the 31 epoch for training data,  the loss is 5.277311171848081 the accuracy is  0.3877
# the 31 epoch for validation data,  the loss is 7.535500459099852 the accuracy is  0.272
# the 32 epoch for training data,  the loss is 6.0396564711731315 the accuracy is  0.389
# the 32 epoch for validation data,  the loss is 8.451431793993347 the accuracy is  0.2752
# the 33 epoch for training data,  the loss is 7.430589281269419 the accuracy is  0.3724
# the 33 epoch for validation data,  the loss is 9.86977958917506 the accuracy is  0.2519
# the 34 epoch for training data,  the loss is 3.690184306469208 the accuracy is  0.4519
# the 34 epoch for validation data,  the loss is 6.032899887129402 the accuracy is  0.2947
# the 35 epoch for training data,  the loss is 4.2361945540060955 the accuracy is  0.4153
# the 35 epoch for validation data,  the loss is 6.666563919117923 the accuracy is  0.2733
# the 36 epoch for training data,  the loss is 3.338960962095408 the accuracy is  0.4521
# the 36 epoch for validation data,  the loss is 5.695466829986576 the accuracy is  0.3007
# the 37 epoch for training data,  the loss is 3.63556414977755 the accuracy is  0.4745
# the 37 epoch for validation data,  the loss is 6.164360304430789 the accuracy is  0.3097
# the 38 epoch for training data,  the loss is 3.105208438850282 the accuracy is  0.4722
# the 38 epoch for validation data,  the loss is 5.653109748986426 the accuracy is  0.2908
# the 39 epoch for training data,  the loss is 3.1486477532247164 the accuracy is  0.4744
# the 39 epoch for validation data,  the loss is 5.696284206120923 the accuracy is  0.3024
# the best model is in 39 the accuracy is 0.3024
# the loss is 11.165131829479485 the accuracy is  0.2574

# %%
c = one_layer_classifier(lamda=0, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 2.9730223993079044 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 2.9494820921155 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 2.1726386483928453 the accuracy is  0.241
# the 1 epoch for validation data,  the loss is 2.196877393900176 the accuracy is  0.2337
# the 2 epoch for training data,  the loss is 2.0444134996578627 the accuracy is  0.2787
# the 2 epoch for validation data,  the loss is 2.084689591084783 the accuracy is  0.2674
# the 3 epoch for training data,  the loss is 1.9798383633573233 the accuracy is  0.3034
# the 3 epoch for validation data,  the loss is 2.0328622524445947 the accuracy is  0.2865
# the 4 epoch for training data,  the loss is 1.9386767198293273 the accuracy is  0.3193
# the 4 epoch for validation data,  the loss is 2.001387882792862 the accuracy is  0.2983
# the 5 epoch for training data,  the loss is 1.9097759266655816 the accuracy is  0.3311
# the 5 epoch for validation data,  the loss is 1.980154692604873 the accuracy is  0.3092
# the 6 epoch for training data,  the loss is 1.8831448564435425 the accuracy is  0.342
# the 6 epoch for validation data,  the loss is 1.9611005936164885 the accuracy is  0.3176
# the 7 epoch for training data,  the loss is 1.8630241705031312 the accuracy is  0.35
# the 7 epoch for validation data,  the loss is 1.9472661688802684 the accuracy is  0.322
# the 8 epoch for training data,  the loss is 1.8461906498954412 the accuracy is  0.3539
# the 8 epoch for validation data,  the loss is 1.9348194222295945 the accuracy is  0.3233
# the 9 epoch for training data,  the loss is 1.8313440898064222 the accuracy is  0.3597
# the 9 epoch for validation data,  the loss is 1.9266147920831638 the accuracy is  0.3282
# the 10 epoch for training data,  the loss is 1.8178391159622898 the accuracy is  0.3649
# the 10 epoch for validation data,  the loss is 1.9177200371720293 the accuracy is  0.3322
# the 11 epoch for training data,  the loss is 1.804878969604114 the accuracy is  0.3709
# the 11 epoch for validation data,  the loss is 1.9109159201684895 the accuracy is  0.3369
# the 12 epoch for training data,  the loss is 1.7942859052242743 the accuracy is  0.3745
# the 12 epoch for validation data,  the loss is 1.9039898423273436 the accuracy is  0.3419
# the 13 epoch for training data,  the loss is 1.7848808522529525 the accuracy is  0.3773
# the 13 epoch for validation data,  the loss is 1.898361495622599 the accuracy is  0.3436
# the 14 epoch for training data,  the loss is 1.775973714318731 the accuracy is  0.3817
# the 14 epoch for validation data,  the loss is 1.8930319701562188 the accuracy is  0.3454
# the 15 epoch for training data,  the loss is 1.76731381793076 the accuracy is  0.3873
# the 15 epoch for validation data,  the loss is 1.8905561128606438 the accuracy is  0.3495
# the 16 epoch for training data,  the loss is 1.759028600288707 the accuracy is  0.3912
# the 16 epoch for validation data,  the loss is 1.8852753386150547 the accuracy is  0.3502
# the 17 epoch for training data,  the loss is 1.7511915666828812 the accuracy is  0.3949
# the 17 epoch for validation data,  the loss is 1.881054007870877 the accuracy is  0.3509
# the 18 epoch for training data,  the loss is 1.7452592087392218 the accuracy is  0.3997
# the 18 epoch for validation data,  the loss is 1.876670857131071 the accuracy is  0.3528
# the 19 epoch for training data,  the loss is 1.7384390020816922 the accuracy is  0.4019
# the 19 epoch for validation data,  the loss is 1.8747972218243965 the accuracy is  0.3532
# the 20 epoch for training data,  the loss is 1.7311596489937169 the accuracy is  0.403
# the 20 epoch for validation data,  the loss is 1.8706875176276303 the accuracy is  0.3552
# the 21 epoch for training data,  the loss is 1.7251385262239474 the accuracy is  0.406
# the 21 epoch for validation data,  the loss is 1.867498393590261 the accuracy is  0.3565
# the 22 epoch for training data,  the loss is 1.7201158389112357 the accuracy is  0.4109
# the 22 epoch for validation data,  the loss is 1.864871599285083 the accuracy is  0.358
# the 23 epoch for training data,  the loss is 1.7146051781745721 the accuracy is  0.4102
# the 23 epoch for validation data,  the loss is 1.8625117223547727 the accuracy is  0.3577
# the 24 epoch for training data,  the loss is 1.7092678860679344 the accuracy is  0.4135
# the 24 epoch for validation data,  the loss is 1.8606851808831606 the accuracy is  0.3598
# the 25 epoch for training data,  the loss is 1.7049512719361775 the accuracy is  0.4128
# the 25 epoch for validation data,  the loss is 1.8595998196469752 the accuracy is  0.3593
# the 26 epoch for training data,  the loss is 1.7017921506781677 the accuracy is  0.4146
# the 26 epoch for validation data,  the loss is 1.857998343630713 the accuracy is  0.3596
# the 27 epoch for training data,  the loss is 1.6965638581682556 the accuracy is  0.4202
# the 27 epoch for validation data,  the loss is 1.8557353440134008 the accuracy is  0.3623
# the 28 epoch for training data,  the loss is 1.6908116122788814 the accuracy is  0.4228
# the 28 epoch for validation data,  the loss is 1.8531016097601554 the accuracy is  0.3633
# the 29 epoch for training data,  the loss is 1.6871599928454635 the accuracy is  0.4233
# the 29 epoch for validation data,  the loss is 1.8523075053462388 the accuracy is  0.3631
# the 30 epoch for training data,  the loss is 1.6832625693770664 the accuracy is  0.4237
# the 30 epoch for validation data,  the loss is 1.849687771587908 the accuracy is  0.3653
# the 31 epoch for training data,  the loss is 1.6789925820888951 the accuracy is  0.4281
# the 31 epoch for validation data,  the loss is 1.8468911059570254 the accuracy is  0.3648
# the 32 epoch for training data,  the loss is 1.6754971074216465 the accuracy is  0.4264
# the 32 epoch for validation data,  the loss is 1.8476417164986465 the accuracy is  0.3665
# the 33 epoch for training data,  the loss is 1.6715848610872133 the accuracy is  0.4302
# the 33 epoch for validation data,  the loss is 1.8455127921161154 the accuracy is  0.3668
# the 34 epoch for training data,  the loss is 1.6678757453403055 the accuracy is  0.431
# the 34 epoch for validation data,  the loss is 1.8437677487984983 the accuracy is  0.3663
# the 35 epoch for training data,  the loss is 1.6659130020760105 the accuracy is  0.4297
# the 35 epoch for validation data,  the loss is 1.8443561200404053 the accuracy is  0.3659
# the 36 epoch for training data,  the loss is 1.6617318891535178 the accuracy is  0.4308
# the 36 epoch for validation data,  the loss is 1.8426064785673064 the accuracy is  0.3671
# the 37 epoch for training data,  the loss is 1.6593687203887886 the accuracy is  0.4324
# the 37 epoch for validation data,  the loss is 1.843051572576956 the accuracy is  0.3681
# the 38 epoch for training data,  the loss is 1.6547135290567483 the accuracy is  0.434
# the 38 epoch for validation data,  the loss is 1.8402614540355577 the accuracy is  0.3668
# the 39 epoch for training data,  the loss is 1.651787859249235 the accuracy is  0.4339
# the 39 epoch for validation data,  the loss is 1.839433489317682 the accuracy is  0.3707
# the best model is in 39 the accuracy is 0.3707
# the loss is 1.8057531383466132 the accuracy is  0.3717

# %%
c = one_layer_classifier(lamda=0.1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 4.973382790700071 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 4.949842483507666 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 4.076062530095694 the accuracy is  0.2423
# the 1 epoch for validation data,  the loss is 4.100148714930395 the accuracy is  0.2341
# the 2 epoch for training data,  the loss is 3.8642128189328018 the accuracy is  0.2811
# the 2 epoch for validation data,  the loss is 3.9037842680570476 the accuracy is  0.2694
# the 3 epoch for training data,  the loss is 3.721527340555889 the accuracy is  0.3071
# the 3 epoch for validation data,  the loss is 3.7730907334317987 the accuracy is  0.288
# the 4 epoch for training data,  the loss is 3.6066238341165313 the accuracy is  0.3232
# the 4 epoch for validation data,  the loss is 3.667048628779077 the accuracy is  0.3021
# the 5 epoch for training data,  the loss is 3.507863194424459 the accuracy is  0.3364
# the 5 epoch for validation data,  the loss is 3.575062734667413 the accuracy is  0.3138
# the 6 epoch for training data,  the loss is 3.414975087234846 the accuracy is  0.3483
# the 6 epoch for validation data,  the loss is 3.4888583776770705 the accuracy is  0.3231
# the 7 epoch for training data,  the loss is 3.331870897681089 the accuracy is  0.3552
# the 7 epoch for validation data,  the loss is 3.4110447114951836 the accuracy is  0.3293
# the 8 epoch for training data,  the loss is 3.2550253543753085 the accuracy is  0.3622
# the 8 epoch for validation data,  the loss is 3.3375813965713297 the accuracy is  0.3322
# the 9 epoch for training data,  the loss is 3.183175960002475 the accuracy is  0.3666
# the 9 epoch for validation data,  the loss is 3.271346775282876 the accuracy is  0.3368
# the 10 epoch for training data,  the loss is 3.1152434319107005 the accuracy is  0.3734
# the 10 epoch for validation data,  the loss is 3.2069202258662353 the accuracy is  0.3404
# the 11 epoch for training data,  the loss is 3.0504364674218 the accuracy is  0.3797
# the 11 epoch for validation data,  the loss is 3.147110622335246 the accuracy is  0.3475
# the 12 epoch for training data,  the loss is 2.9904914190973892 the accuracy is  0.3848
# the 12 epoch for validation data,  the loss is 3.089785449943225 the accuracy is  0.3487
# the 13 epoch for training data,  the loss is 2.933843499111893 the accuracy is  0.3881
# the 13 epoch for validation data,  the loss is 3.035772828183308 the accuracy is  0.3532
# the 14 epoch for training data,  the loss is 2.879919859227263 the accuracy is  0.3949
# the 14 epoch for validation data,  the loss is 2.9841615432281294 the accuracy is  0.3544
# the 15 epoch for training data,  the loss is 2.828278267645575 the accuracy is  0.3971
# the 15 epoch for validation data,  the loss is 2.9376764646111297 the accuracy is  0.3578
# the 16 epoch for training data,  the loss is 2.7789662053368622 the accuracy is  0.404
# the 16 epoch for validation data,  the loss is 2.8901881303735166 the accuracy is  0.3593
# the 17 epoch for training data,  the loss is 2.7318673375621643 the accuracy is  0.4068
# the 17 epoch for validation data,  the loss is 2.845405492928636 the accuracy is  0.3634
# the 18 epoch for training data,  the loss is 2.6884797016179336 the accuracy is  0.412
# the 18 epoch for validation data,  the loss is 2.8026217115342975 the accuracy is  0.363
# the 19 epoch for training data,  the loss is 2.6460764814996685 the accuracy is  0.4117
# the 19 epoch for validation data,  the loss is 2.763933084358424 the accuracy is  0.3633
# the 20 epoch for training data,  the loss is 2.6044766904434367 the accuracy is  0.4155
# the 20 epoch for validation data,  the loss is 2.724154733415216 the accuracy is  0.367
# the 21 epoch for training data,  the loss is 2.565787667125078 the accuracy is  0.4156
# the 21 epoch for validation data,  the loss is 2.687157798133347 the accuracy is  0.3692
# the 22 epoch for training data,  the loss is 2.529616241900425 the accuracy is  0.4223
# the 22 epoch for validation data,  the loss is 2.652009087053881 the accuracy is  0.3717
# the 23 epoch for training data,  the loss is 2.49426345133861 the accuracy is  0.4207
# the 23 epoch for validation data,  the loss is 2.618669551222831 the accuracy is  0.3718
# the 24 epoch for training data,  the loss is 2.460416802361298 the accuracy is  0.4241
# the 24 epoch for validation data,  the loss is 2.587127334899664 the accuracy is  0.3719
# the 25 epoch for training data,  the loss is 2.428915196449997 the accuracy is  0.4248
# the 25 epoch for validation data,  the loss is 2.557712651537277 the accuracy is  0.3721
# the 26 epoch for training data,  the loss is 2.399694297716473 the accuracy is  0.4249
# the 26 epoch for validation data,  the loss is 2.5288902448533364 the accuracy is  0.3714
# the 27 epoch for training data,  the loss is 2.3696448717236356 the accuracy is  0.425
# the 27 epoch for validation data,  the loss is 2.500471684411885 the accuracy is  0.3779
# the 28 epoch for training data,  the loss is 2.3401552134131625 the accuracy is  0.4304
# the 28 epoch for validation data,  the loss is 2.472879287775114 the accuracy is  0.3772
# the 29 epoch for training data,  the loss is 2.3138085855225112 the accuracy is  0.4304
# the 29 epoch for validation data,  the loss is 2.447895322684288 the accuracy is  0.3757
# the 30 epoch for training data,  the loss is 2.28814251098032 the accuracy is  0.4318
# the 30 epoch for validation data,  the loss is 2.422435962442867 the accuracy is  0.378
# the 31 epoch for training data,  the loss is 2.2632287772687074 the accuracy is  0.4333
# the 31 epoch for validation data,  the loss is 2.3978578365314274 the accuracy is  0.3807
# the 32 epoch for training data,  the loss is 2.2398183515649968 the accuracy is  0.4342
# the 32 epoch for validation data,  the loss is 2.3775688797453856 the accuracy is  0.3824
# the 33 epoch for training data,  the loss is 2.217071424908312 the accuracy is  0.4374
# the 33 epoch for validation data,  the loss is 2.3553158178992315 the accuracy is  0.379
# the 34 epoch for training data,  the loss is 2.195254022180909 the accuracy is  0.4383
# the 34 epoch for validation data,  the loss is 2.3341126722758845 the accuracy is  0.3813
# the 35 epoch for training data,  the loss is 2.1760413114093025 the accuracy is  0.4361
# the 35 epoch for validation data,  the loss is 2.3159899017041368 the accuracy is  0.3802
# the 36 epoch for training data,  the loss is 2.1552546526556493 the accuracy is  0.4395
# the 36 epoch for validation data,  the loss is 2.2967784081705673 the accuracy is  0.3832
# the 37 epoch for training data,  the loss is 2.1372593067131995 the accuracy is  0.4389
# the 37 epoch for validation data,  the loss is 2.2801206197995465 the accuracy is  0.3832
# the 38 epoch for training data,  the loss is 2.117435188421236 the accuracy is  0.4424
# the 38 epoch for validation data,  the loss is 2.2609757158052446 the accuracy is  0.3857
# the 39 epoch for training data,  the loss is 2.1003086729906992 the accuracy is  0.442
# the 39 epoch for validation data,  the loss is 2.244768468727167 the accuracy is  0.3869
# the best model is in 39 the accuracy is 0.3869
# the loss is 2.2008715457462746 the accuracy is  0.3876

# %%
c = one_layer_classifier(lamda=1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 22.976626313229566 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 22.95308600603716 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 15.440121949533026 the accuracy is  0.2524
# the 1 epoch for validation data,  the loss is 15.462938413633697 the accuracy is  0.2422
# the 2 epoch for training data,  the loss is 10.887983947407733 the accuracy is  0.3006
# the 2 epoch for validation data,  the loss is 10.922324360479454 the accuracy is  0.2875
# the 3 epoch for training data,  the loss is 7.885995640067847 the accuracy is  0.3309
# the 3 epoch for validation data,  the loss is 7.927776308428179 the accuracy is  0.3119
# the 4 epoch for training data,  the loss is 5.892422661400362 the accuracy is  0.3548
# the 4 epoch for validation data,  the loss is 5.938725094567168 the accuracy is  0.3344
# the 5 epoch for training data,  the loss is 4.566351548122317 the accuracy is  0.3672
# the 5 epoch for validation data,  the loss is 4.615284867884206 the accuracy is  0.3392
# the 6 epoch for training data,  the loss is 3.6789650755644008 the accuracy is  0.376
# the 6 epoch for validation data,  the loss is 3.7309932935357804 the accuracy is  0.3489
# the 7 epoch for training data,  the loss is 3.0883889726551965 the accuracy is  0.382
# the 7 epoch for validation data,  the loss is 3.1418156040468035 the accuracy is  0.354
# the 8 epoch for training data,  the loss is 2.694078457711283 the accuracy is  0.3883
# the 8 epoch for validation data,  the loss is 2.747377726562158 the accuracy is  0.3601
# the 9 epoch for training data,  the loss is 2.4313875718670275 the accuracy is  0.3884
# the 9 epoch for validation data,  the loss is 2.487157584811204 the accuracy is  0.3565
# the 10 epoch for training data,  the loss is 2.2551061401484898 the accuracy is  0.393
# the 10 epoch for validation data,  the loss is 2.31097091774773 the accuracy is  0.362
# the 11 epoch for training data,  the loss is 2.1365897254250203 the accuracy is  0.3945
# the 11 epoch for validation data,  the loss is 2.1941884184768954 the accuracy is  0.3627
# the 12 epoch for training data,  the loss is 2.0588456840689267 the accuracy is  0.3942
# the 12 epoch for validation data,  the loss is 2.116175937888144 the accuracy is  0.364
# the 13 epoch for training data,  the loss is 2.0064998911448573 the accuracy is  0.3974
# the 13 epoch for validation data,  the loss is 2.063849816761493 the accuracy is  0.3636
# the 14 epoch for training data,  the loss is 1.9716783721080895 the accuracy is  0.398
# the 14 epoch for validation data,  the loss is 2.0281731201880544 the accuracy is  0.3637
# the 15 epoch for training data,  the loss is 1.9481986316769802 the accuracy is  0.3965
# the 15 epoch for validation data,  the loss is 2.0082235706807556 the accuracy is  0.363
# the 16 epoch for training data,  the loss is 1.9321144459692197 the accuracy is  0.3982
# the 16 epoch for validation data,  the loss is 1.9912374430333775 the accuracy is  0.3658
# the 17 epoch for training data,  the loss is 1.9209497342493718 the accuracy is  0.3962
# the 17 epoch for validation data,  the loss is 1.9798710109146387 the accuracy is  0.3644
# the 18 epoch for training data,  the loss is 1.9149120255541874 the accuracy is  0.3985
# the 18 epoch for validation data,  the loss is 1.97283410404433 the accuracy is  0.3628
# the 19 epoch for training data,  the loss is 1.9104087548533173 the accuracy is  0.3961
# the 19 epoch for validation data,  the loss is 1.9700465868408785 the accuracy is  0.3619
# the 20 epoch for training data,  the loss is 1.9055144898885714 the accuracy is  0.3985
# the 20 epoch for validation data,  the loss is 1.9645821829813035 the accuracy is  0.3622
# the 21 epoch for training data,  the loss is 1.9031309321060088 the accuracy is  0.4
# the 21 epoch for validation data,  the loss is 1.9622769567266563 the accuracy is  0.3638
# the 22 epoch for training data,  the loss is 1.9026512640039277 the accuracy is  0.4005
# the 22 epoch for validation data,  the loss is 1.9606336770685904 the accuracy is  0.3657
# the 23 epoch for training data,  the loss is 1.9012021382630122 the accuracy is  0.399
# the 23 epoch for validation data,  the loss is 1.959608633766319 the accuracy is  0.3614
# the 24 epoch for training data,  the loss is 1.900213107646095 the accuracy is  0.3989
# the 24 epoch for validation data,  the loss is 1.9595415658314637 the accuracy is  0.3632
# the 25 epoch for training data,  the loss is 1.9002992529311433 the accuracy is  0.396
# the 25 epoch for validation data,  the loss is 1.960283273127707 the accuracy is  0.3628
# the 26 epoch for training data,  the loss is 1.9015431656632797 the accuracy is  0.3973
# the 26 epoch for validation data,  the loss is 1.9604754270241336 the accuracy is  0.3625
# the 27 epoch for training data,  the loss is 1.9007356959427941 the accuracy is  0.3997
# the 27 epoch for validation data,  the loss is 1.9598349200750254 the accuracy is  0.3632
# the 28 epoch for training data,  the loss is 1.8989631806336515 the accuracy is  0.4013
# the 28 epoch for validation data,  the loss is 1.9584738004959055 the accuracy is  0.364
# the 29 epoch for training data,  the loss is 1.899400891189046 the accuracy is  0.4018
# the 29 epoch for validation data,  the loss is 1.9585929134142708 the accuracy is  0.3638
# the 30 epoch for training data,  the loss is 1.8992187300620367 the accuracy is  0.401
# the 30 epoch for validation data,  the loss is 1.9575126025725793 the accuracy is  0.3654
# the 31 epoch for training data,  the loss is 1.8989281654008194 the accuracy is  0.4009
# the 31 epoch for validation data,  the loss is 1.9566498668308552 the accuracy is  0.3658
# the 32 epoch for training data,  the loss is 1.8987506709494704 the accuracy is  0.3988
# the 32 epoch for validation data,  the loss is 1.9588225193743645 the accuracy is  0.3621
# the 33 epoch for training data,  the loss is 1.898678059100062 the accuracy is  0.4014
# the 33 epoch for validation data,  the loss is 1.957675412302315 the accuracy is  0.3651
# the 34 epoch for training data,  the loss is 1.898386248189189 the accuracy is  0.4017
# the 34 epoch for validation data,  the loss is 1.9570903461678788 the accuracy is  0.3639
# the 35 epoch for training data,  the loss is 1.8999900932519844 the accuracy is  0.3985
# the 35 epoch for validation data,  the loss is 1.9581886226373708 the accuracy is  0.3658
# the 36 epoch for training data,  the loss is 1.898681678798836 the accuracy is  0.3964
# the 36 epoch for validation data,  the loss is 1.9582893221591957 the accuracy is  0.362
# the 37 epoch for training data,  the loss is 1.8996421063379767 the accuracy is  0.3984
# the 37 epoch for validation data,  the loss is 1.9593026789710724 the accuracy is  0.3626
# the 38 epoch for training data,  the loss is 1.8980027087472657 the accuracy is  0.401
# the 38 epoch for validation data,  the loss is 1.9573625008910016 the accuracy is  0.3638
# the 39 epoch for training data,  the loss is 1.8986750198604445 the accuracy is  0.4008
# the 39 epoch for validation data,  the loss is 1.9583593660717804 the accuracy is  0.3629
# the best model is in 39 the accuracy is 0.3629
# the loss is 1.9376345694790984 the accuracy is  0.3784
