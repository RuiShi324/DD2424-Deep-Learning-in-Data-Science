# %%
import pickle
import pandas as pd
import numpy as np
from numpy import matlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1 Training a multi-linear classifier

# %%
def LoadBatch(filename):
    """ Copied from the dataset website """
    with open('../Datasets/'+filename, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    
    X = dict[b'data'].transpose()
    Y = pd.get_dummies(dict[b'labels']).transpose()
    Y = Y.to_numpy()
    y = np.array(dict[b'labels']).transpose()
    return X, Y, y

# %%
X1, Y1, y1 = LoadBatch('data_batch_1')
X2, Y2, y2 = LoadBatch('data_batch_2')
X3, Y3, y3 = LoadBatch('data_batch_3')
X4, Y4, y4 = LoadBatch('data_batch_4')
X5, Y5, y5 = LoadBatch('data_batch_5')
X6, Y6, y6 = LoadBatch('test_batch')

# %%
trainX = np.concatenate((X1, X2, X3, X4), axis=1)
#print(trainX)
#print(len(trainX))
#print(len(trainX[0]))
validationX = X5
testX = X6

trainY = np.concatenate((Y1, Y2, Y3, Y4), axis=1)
#print(trainY)
#print(len(trainY))
#print(len(trainY[0]))
validationY = Y5
testY = Y6

trainy = np.concatenate((y1, y2, y3, y4), axis=0)
#print(trainy)
#print(len(trainy))
validationy = y5
testy = y6

# %%
def load_data(directory):
    
    # load data as a normalized way
    
    C=10  #number of classes
    X = LoadBatch(directory)[b'data'].transpose()
    # normalize the raw input data
    X_mean = X.mean(axis=1).reshape(-1,1)
    X_std = X.std(axis=1).reshape(-1,1)
    X = (X-X_mean)/X_std
    y = np.array(LoadBatch(directory)[b'labels'])
    #one-hot representation of the label for each image
    Y = np.eye(C, dtype=int)[y].transpose()
    return X, Y, y

def LoadBatch(filename):
    """ Copied from the dataset website """
    with open(filename, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %% [markdown]
# #### Read in and store the training, validation and test data.

# %%
Xtr, Ytr, ytr = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_1")
Xva, Yva, yva = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_2")
Xte, Yte, yte = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/test_batch")

# %%
print(Xtr.shape[1])
print(Ytr.shape[0], Ytr.shape[1])
# Out:
# 10000
# 10 10000

# %% [markdown]
# ### Pro-process the raw input data

# %%
# trainX = np.concatenate((X1, X2, X3, X4), axis=1)
# #print(trainX)
# #print(len(trainX))
# #print(len(trainX[0]))
# validationX = X5
# testX = X6


# mean_X = trainX.mean(axis=1).reshape(3072, 1)
# #print(type(mean_X))
# #print(mean_X)
# std_X = trainX.std(axis=1).reshape(3072, 1)
# #print(std_X)
# #print(len(std_X))

# mean_X_validation = validationX.mean(axis=1).reshape(3072, 1)
# std_X_validation = validationX.std(axis=1).reshape(3072, 1)

# mean_X_test = testX.mean(axis=1).reshape(3072, 1)
# std_X_test = testX.std(axis=1).reshape(3072, 1)

# trainX = trainX - matlib.repmat(mean_X, 1, 40000)
# trainX = trainX / matlib.repmat(std_X, 1, 40000)
# #print(trainX[0])
# validationX = validationX - matlib.repmat(mean_X_validation, 1, 10000)
# validationX = validationX / matlib.repmat(std_X_validation, 1, 10000)
# testX = testX -matlib.repmat(mean_X_test, 1, 10000)
# testX = testX / matlib.repmat(std_X_test, 1, 10000)

# %% [markdown]
# ### Define some functions

# %%
def ComputeGradsNumSlow( X, Y, P, W, b, h,lamda):
        
        # centered difference formula 
        
        k = W.shape[0]
        d = X.shape[0]

        grad_W = np.zeros(W.shape)
        grad_b = np.zeros((k, 1))   

        for i in range(len(b)):
            b_try = np.array(b)
            b_try[i] -= h
            c1 = compute_cost(X, Y, W, b_try,lamda)

            b_try = np.array(b)
            b_try[i] += h
            c2 = compute_cost(X, Y, W, b_try,lamda)

            grad_b[i] = (c2-c1) / (2*h)

        for i in range(W.shape[0]):
            for j in range(W.shape[1]):
                W_try = np.array(W)
                W_try[i,j] -= h
                c1 = compute_cost(X, Y, W_try, b,lamda)

                W_try = np.array(W)
                W_try[i,j] += h
                c2 = compute_cost(X, Y, W_try, b, lamda)

                grad_W[i,j] = (c2-c1) / (2*h)

        return [grad_W, grad_b]
    
def load_label_names(self):
    return ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
        

def ini_parameters(X, Y):
    
    #generate w and b according to the shape of inputs   
    std=np.sqrt(2/X.shape[0]) 
    #std=0.01
    np.random.seed(100)
    W = std*np.random.randn(Y.shape[0],X.shape[0])+0
    np.random.seed(100)
    b = std*np.random.randn(Y.shape[0],1)+0
    return W, b
    
    
def evaluate_classifier(X, W, b):
        
    # Write a function that evaluates the network function                                            
    
        assert(X.shape[0]== W.shape[1])
        s=np.dot(W, X)+b
        #print(s.shape[0], s.shape[1])
        return  sigmoid(s)
    
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=0)    


def compute_cost(X, Y, y, W, b, lamda,svm=False):
        
    # calculate full loss function
    if svm ==False:
        L = cross_entropy(X, Y, W, b)+np.sum(W**2)*lamda
    elif svm==True:
        L = svm_loss(X, y, W, b)+np.sum(W**2)*lamda
    return L
        
    
def cross_entropy(X, Y, W, b):
        
      #define cross entropy loss
    
    cross_entropy_loss = np.dot(Y.transpose(), evaluate_classifier(X,W,b))               
    cross_entropy_loss = np.diag(cross_entropy_loss)
    cross_entropy_loss = -np.log(cross_entropy_loss)
    loss = np.sum(cross_entropy_loss)/ Y.shape[1]
    return loss

def svm_loss(X, y, W, b):
    
    #define svm loss
    
    assert(X.shape[0]== W.shape[1])
    s=np.dot(W, X)+b
    l=np.zeros(s.shape)
    for i in range(s.shape[0]):
        for j in range(s.shape[1]):
            l[i][j]= max(0, s[i][j]-s[y[j]][j]+1)
    loss=np.sum(l)/ X.shape[1]
    return loss   
   
    
def compute_accuracy(X, y, W, b):
        
  #compute the accuracy of the network prediction

    k = np.argmax(evaluate_classifier(X,W,b), axis=0)
    acc=0
    for i in range(X.shape[1]):
        if k[i]==y[i]:
            acc+=1
    acc=acc/X.shape[1]
    return acc
        
    
def compute_gradient(X, Y, W, b,lamda,svm=False):
         
    #evaluate the gradients of the cost function for a mini-batch
    if svm==False:
        P=evaluate_classifier(X, W, b)
    
        g=P-Y
        assert(X.shape[1]== g.shape[1])
        grad_b = np.dot(g,np.ones((X.shape[1],1)))/X.shape[1]
        grad_w = np.dot(g, X.T)/X.shape[1]+2*lamda*W
        return grad_w, grad_b
    else:
        n = X.shape[1]
        d = X.shape[0]
        K = Y.shape[0]
        gradW = np.zeros((K, d))
        gradb = np.zeros((K, 1))

        for i in range(n):
            x = X[:, i]
            y_int = np.where(Y[:, [i]].T[0] == 1)[0][0]
            s = np.dot(W, X[:, [i]]) + b
            for j in range(K):
                if j != y_int:
                    if max(0, s[j] - s[y_int] + 1) != 0:
                        gradW[j] += x
                        gradW[y_int] += -x
                        gradb[j, 0] += 1
                        gradb[y_int, 0] += -1

        gradW /= n
        gradW += lamda * W
        gradb /= n
        return gradW, gradb


def ComputeGradsNum(X, Y, y, W, b, h, lamda):
        
    # finite difference method
    
        k = W.shape[0]
        d = X.shape[0]

        grad_W = np.zeros(W.shape);
        grad_b = np.zeros((k, 1));

        c = compute_cost(X, Y, y, W, b,lamda,svm=False);
        
        
        for i in range(b.shape[0]):
            
            b_try1 = np.array(b)
            b_try2 = np.array(b)
            b_try1[i][0] += h
            b_try2[i][0] -= h
        
            
            c1 = compute_cost(X, Y,y, W, b_try1,lamda,svm=False)
            c2 = compute_cost(X, Y, y,W, b_try2,lamda,svm=False)
            grad_b[i] = (c1-c2) / (2*h)
            
            
        for i in range(W.shape[0]):
            for j in range(W.shape[1]):
                W_try = np.array(W)
                W_try[i,j] += h
                c2 = compute_cost(X, Y,y, W_try, b,lamda,svm=False)
                grad_W[i,j] = (c2-c) / h

        return [grad_W, grad_b]
    
def montage(W):
	""" Display the image for each label in W """
	import matplotlib.pyplot as plt
	fig, ax = plt.subplots(2,5)
	for i in range(2):
		for j in range(5):
			im  = W[5*i+j,:].reshape(32,32,3, order='F')
			sim = (im-np.min(im[:]))/(np.max(im[:])-np.min(im[:]))
			sim = sim.transpose(1,0,2)
			ax[i][j].imshow(sim, interpolation='nearest')
			ax[i][j].set_title("y="+str(5*i+j))
			ax[i][j].axis('off')
	plt.show()

# %%
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    #remember to transpose inputs when using this
    #assert inputs.shape[0] == targets.shape[0]
    if shuffle:
        indices = np.arange(inputs.shape[0])
        np.random.shuffle(indices)
    for start_idx in range(0, inputs.shape[0] - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        return inputs[excerpt], targets[excerpt]

# %%
def sigmoid(x):
    ele = []
    #for i in range(x):
        #ele.append(np.exp(i) / np.exp(i)+ 1)
    return 1 / (1 + np.exp(-x))

# %%
xmini, ymini=iterate_minibatches(Xtr.T, ytr, 100)
xmini=xmini.T
Ymini = np.eye(10, dtype=int)[ymini].transpose()
W, b= ini_parameters(xmini, Ymini)
P=evaluate_classifier(xmini, W, b)
# Out:
# 10 100

# %% [markdown]
# ### Check gradients

# %%
xmini, ymini=iterate_minibatches(Xtr.T, ytr, 100)
xmini=xmini.T
Ymini = np.eye(10, dtype=int)[ymini].transpose()
W, b= ini_parameters(xmini, Ymini)
P=evaluate_classifier(xmini, W, b)
gnw, gnb=ComputeGradsNum(X=xmini, Y= Ymini,y=ymini,  W=W, b=b, h=0.001,lamda=0)
gaw, gab=compute_gradient(X=xmini, Y= Ymini,  W=W,b=b,lamda=0,svm=False)
err=np.abs(gaw-gnw)/(np.abs(gaw)+np.abs(gnw))
print(err)
# Out:
# [[0.00121301 0.00386175 0.00302505 ... 0.00202511 0.00160751 0.00074994]
#  [0.00043719 0.00050799 0.00037732 ... 0.0021566  0.00093341 0.00079176]
#  [0.00080395 0.00059602 0.00139554 ... 0.00055949 0.00051325 0.00047505]
#  ...
#  [0.00021944 0.00023458 0.0002398  ... 0.00039616 0.00056296 0.00049396]
#  [0.0007845  0.0005969  0.00055309 ... 0.00040166 0.00043315 0.00056944]
#  [0.00025196 0.00030337 0.00033024 ... 0.00028696 0.00031394 0.00030471]]

# %% [markdown]
# ### Build the one layer classifier

# %%
class one_layer_classifier():
    
    def __init__(self, lamda=0, n_epochs=40, n_batch=100, eta=0.1, decay_factor=1,svm=False):
    
        self.W, self.b = ini_parameters(Xtr, Ytr)
        self.P = 0
        self.lamda=lamda
        self.n_batch=n_batch
        self.n_epochs=n_epochs
        self.eta = eta
        self.decay_factor=decay_factor
        self.svm=svm
        self.best_b=0
        self.best_w=0
    
    def fit(self,Xtr, Ytr, ytr, Xva, Yva, yva):
        
        trainingloss=[]
        validationloss=[]
        trainingaccuracy=[]
        validationaccuracy=[]
        
        for i in range(self.n_epochs):
            best_model=0
            best_acc=0
            l1=compute_cost(Xtr, Ytr, ytr, self.W, self.b, self.lamda,self.svm)
            trainingloss.append(l1)
            acc=compute_accuracy(Xtr, ytr, self.W, self.b)
            trainingaccuracy.append(acc)
            print("the",format(i),"epoch for training data,"," the loss is", l1, "the accuracy is ",acc)
            l2=compute_cost(Xva, Yva, yva, self.W, self.b, self.lamda,self.svm)
            validationloss.append(l2)
            acc=compute_accuracy(Xva, yva, self.W, self.b)
            if acc>best_acc:
                best_model=i
                best_acc=acc
                self.best_w=self.W
                self.best_b=self.b
            validationaccuracy.append(acc)
            print("the",format(i),"epoch for validation data,"," the loss is", l2, "the accuracy is ",acc)
            
            Xtr, ytr=iterate_minibatches(Xtr.T, ytr, 10000, shuffle=True)
            Xtr=Xtr.T
            Ytr = np.eye(10, dtype=int)[ytr].transpose()
            #print(Xtr.shape,Ytr.shape,ytr.shape)
            
            for i in range(Xtr.shape[1]//self.n_batch):
                
                x_mini_batch = Xtr.T[i*self.n_batch:(i+1)*self.n_batch]
                Y_mini_batch = Ytr.T[i*self.n_batch:(i+1)*self.n_batch]
                
                
                
                gradw, gradb = compute_gradient(x_mini_batch.T, Y_mini_batch.T, self.W, self.b, self.lamda,self.svm)
                self.W-= gradw*self.eta
                self.b-= gradb*self.eta
                
            self.eta = self.eta * self.decay_factor
            
        x = range(1,self.n_epochs+1)    
        plt.plot(x, trainingloss,  label = "training loss" )
        plt.plot(x, validationloss, label = "validation loss" )
        plt.xlabel("epoch")
        plt.ylabel("loss")
        plt.legend()
        plt.title('training and validation loss') 
        plt.show()
        
        x = range(1,self.n_epochs+1)    
        plt.plot(x, trainingaccuracy,  label = "training accuracy" )
        plt.plot(x, validationaccuracy, label = "validation accuracy" )
        plt.xlabel("epoch")
        plt.ylabel("accuracy")
        plt.legend()
        plt.title('training and validation accuracy') 
        plt.show()
        
        #print(self.W,self.b)
        montage(self.W)  
        print("the last model is in",best_model, "the accuracy is",best_acc)
        
    def predict(self, Xte, Yte, yte):
        
        l=compute_cost(Xte, Yte,yte, self.best_w, self.best_b, self.lamda,self.svm)
        acc=compute_accuracy(Xte, yte, self.best_w, self.best_b)
        print("the loss is", l, "the accuracy is ",acc)

# %%
c = one_layer_classifier(lamda=0, n_epochs=40, n_batch=100, eta=0.1, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\KTH\study\Grade1\P4\DD2424 Deep Learning in Data Science\Assignment\1\Bonus\assignment1_bonus.ipynb Cell 20' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000018?line=0'>1</a> c = one_layer_classifier(lamda=0, n_epochs=40, n_batch=100, eta=0.1, decay_factor=1,svm=False)
# ----> <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000018?line=1'>2</a> c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
#       <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000018?line=2'>3</a> c.predict(Xte, Yte, yte)
#
# d:\KTH\study\Grade1\P4\DD2424 Deep Learning in Data Science\Assignment\1\Bonus\assignment1_bonus.ipynb Cell 19' in one_layer_classifier.fit(self, Xtr, Ytr, ytr, Xva, Yva, yva)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000017?line=23'>24</a> best_model=0
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000017?line=24'>25</a> best_acc=0
# ---> <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000017?line=25'>26</a> l1=compute_cost(Xtr, Ytr, ytr, self.W, self.b, self.lamda,self.svm)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000017?line=26'>27</a> trainingloss.append(l1)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000017?line=27'>28</a> acc=compute_accuracy(Xtr, ytr, self.W, self.b)
#
# d:\KTH\study\Grade1\P4\DD2424 Deep Learning in Data Science\Assignment\1\Bonus\assignment1_bonus.ipynb Cell 13' in compute_cost(X, Y, y, W, b, lamda, svm)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=63'>64</a> def compute_cost(X, Y, y, W, b, lamda,svm=False):
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=64'>65</a>
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=65'>66</a>     # calculate full loss function
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=66'>67</a>     if svm ==False:
# ---> <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=67'>68</a>         L = cross_entropy(X, Y, W, b)+np.sum(W**2)*lamda
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=68'>69</a>     elif svm==True:
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=69'>70</a>         L = svm_loss(X, y, W, b)+np.sum(W**2)*lamda
#
# d:\KTH\study\Grade1\P4\DD2424 Deep Learning in Data Science\Assignment\1\Bonus\assignment1_bonus.ipynb Cell 13' in cross_entropy(X, Y, W, b)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=73'>74</a> def cross_entropy(X, Y, W, b):
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=74'>75</a>
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=75'>76</a>       #define cross entropy loss
# ---> <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=77'>78</a>     cross_entropy_loss = np.dot(Y.transpose(), evaluate_classifier(X,W,b))
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=78'>79</a>     cross_entropy_loss = np.diag(cross_entropy_loss)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=79'>80</a>     cross_entropy_loss = -np.log(cross_entropy_loss)
#
# d:\KTH\study\Grade1\P4\DD2424 Deep Learning in Data Science\Assignment\1\Bonus\assignment1_bonus.ipynb Cell 13' in evaluate_classifier(X, W, b)
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=55'>56</a> assert(X.shape[0]== W.shape[1])
#      <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=56'>57</a> s=np.dot(W, X)+b
# ---> <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000012?line=57'>58</a> return  sigmoid(s)
#
# d:\KTH\study\Grade1\P4\DD2424 Deep Learning in Data Science\Assignment\1\Bonus\assignment1_bonus.ipynb Cell 15' in sigmoid(x)
#       <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000038?line=0'>1</a> def sigmoid(x):
#       <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000038?line=1'>2</a>     ele = []
# ----> <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000038?line=2'>3</a>     for i in range(x):
#       <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000038?line=3'>4</a>         ele.append(np.exp(i) / np.exp(i)+ 1)
#       <a href='vscode-notebook-cell:/d%3A/KTH/study/Grade1/P4/DD2424%20Deep%20Learning%20in%20Data%20Science/Assignment/1/Bonus/assignment1_bonus.ipynb#ch0000038?line=4'>5</a>     return ele
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
c = one_layer_classifier(lamda=0, n_epochs=40, n_batch=100, eta=0.005, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 0.8540232985098619 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 0.8534959953270141 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 0.6349394979288678 the accuracy is  0.2735
# the 1 epoch for validation data,  the loss is 0.6521983874261471 the accuracy is  0.2484
# the 2 epoch for training data,  the loss is 0.679135053578902 the accuracy is  0.3222
# the 2 epoch for validation data,  the loss is 0.707207052184956 the accuracy is  0.2871
# the 3 epoch for training data,  the loss is 0.7328779724811851 the accuracy is  0.3418
# the 3 epoch for validation data,  the loss is 0.7715038903392943 the accuracy is  0.3038
# the 4 epoch for training data,  the loss is 0.7740268393009148 the accuracy is  0.3707
# the 4 epoch for validation data,  the loss is 0.82133192459328 the accuracy is  0.312
# the 5 epoch for training data,  the loss is 0.8178015525978657 the accuracy is  0.3849
# the 5 epoch for validation data,  the loss is 0.8728391786077653 the accuracy is  0.3279
# the 6 epoch for training data,  the loss is 0.8660738362594622 the accuracy is  0.3887
# the 6 epoch for validation data,  the loss is 0.9280093898520141 the accuracy is  0.3231
# the 7 epoch for training data,  the loss is 0.9109301247668314 the accuracy is  0.4087
# the 7 epoch for validation data,  the loss is 0.9816036785191363 the accuracy is  0.338
# the 8 epoch for training data,  the loss is 0.9437441534986254 the accuracy is  0.4208
# the 8 epoch for validation data,  the loss is 1.020663175599989 the accuracy is  0.3445
# the 9 epoch for training data,  the loss is 0.9900678914292849 the accuracy is  0.4289
# the 9 epoch for validation data,  the loss is 1.0719285506183742 the accuracy is  0.3496
# the 10 epoch for training data,  the loss is 1.0228130376018765 the accuracy is  0.4302
# the 10 epoch for validation data,  the loss is 1.1124800709398694 the accuracy is  0.3422
# the 11 epoch for training data,  the loss is 1.0413598351544058 the accuracy is  0.4449
# the 11 epoch for validation data,  the loss is 1.1387999456777085 the accuracy is  0.3553
# the 12 epoch for training data,  the loss is 1.0591344202444373 the accuracy is  0.4469
# the 12 epoch for validation data,  the loss is 1.1639531370205571 the accuracy is  0.3535
# the 13 epoch for training data,  the loss is 1.0860597545415667 the accuracy is  0.4483
# the 13 epoch for validation data,  the loss is 1.1952852865109374 the accuracy is  0.3537
# the 14 epoch for training data,  the loss is 1.127443927191578 the accuracy is  0.4525
# the 14 epoch for validation data,  the loss is 1.2407391936246117 the accuracy is  0.3528
# the 15 epoch for training data,  the loss is 1.1213127536061753 the accuracy is  0.461
# the 15 epoch for validation data,  the loss is 1.2446045420946634 the accuracy is  0.3621
# the 16 epoch for training data,  the loss is 1.1418595169028434 the accuracy is  0.456
# the 16 epoch for validation data,  the loss is 1.2697836129255817 the accuracy is  0.3482
# the 17 epoch for training data,  the loss is 1.145748908108745 the accuracy is  0.465
# the 17 epoch for validation data,  the loss is 1.2790298069882025 the accuracy is  0.359
# the 18 epoch for training data,  the loss is 1.1764011323097794 the accuracy is  0.4679
# the 18 epoch for validation data,  the loss is 1.3153402301655168 the accuracy is  0.3589
# the 19 epoch for training data,  the loss is 1.2010423671957364 the accuracy is  0.4626
# the 19 epoch for validation data,  the loss is 1.3485087293656841 the accuracy is  0.3504
# the 20 epoch for training data,  the loss is 1.2070381944501645 the accuracy is  0.4764
# the 20 epoch for validation data,  the loss is 1.3567643850208257 the accuracy is  0.3649
# the 21 epoch for training data,  the loss is 1.2131617646887636 the accuracy is  0.4634
# the 21 epoch for validation data,  the loss is 1.3708436802653512 the accuracy is  0.359
# the 22 epoch for training data,  the loss is 1.2264539266681236 the accuracy is  0.4828
# the 22 epoch for validation data,  the loss is 1.384084262345101 the accuracy is  0.3708
# the 23 epoch for training data,  the loss is 1.2418556531479852 the accuracy is  0.4796
# the 23 epoch for validation data,  the loss is 1.408360174339415 the accuracy is  0.3646
# the 24 epoch for training data,  the loss is 1.2343317197074593 the accuracy is  0.4799
# the 24 epoch for validation data,  the loss is 1.4061779138351191 the accuracy is  0.3673
# the 25 epoch for training data,  the loss is 1.2571724175108079 the accuracy is  0.4737
# the 25 epoch for validation data,  the loss is 1.4381064589563082 the accuracy is  0.359
# the 26 epoch for training data,  the loss is 1.257535798184536 the accuracy is  0.4894
# the 26 epoch for validation data,  the loss is 1.4376324721453513 the accuracy is  0.3685
# the 27 epoch for training data,  the loss is 1.2839735724484196 the accuracy is  0.4898
# the 27 epoch for validation data,  the loss is 1.4697537888278345 the accuracy is  0.3753
# the 28 epoch for training data,  the loss is 1.2715967139056676 the accuracy is  0.4984
# the 28 epoch for validation data,  the loss is 1.462853137838231 the accuracy is  0.3687
# the 29 epoch for training data,  the loss is 1.2950696332136702 the accuracy is  0.4831
# the 29 epoch for validation data,  the loss is 1.4895923141282004 the accuracy is  0.3598
# the 30 epoch for training data,  the loss is 1.3032840618912782 the accuracy is  0.4929
# the 30 epoch for validation data,  the loss is 1.500910267645799 the accuracy is  0.3717
# the 31 epoch for training data,  the loss is 1.3258260961043633 the accuracy is  0.4931
# the 31 epoch for validation data,  the loss is 1.5269898205731571 the accuracy is  0.3654
# the 32 epoch for training data,  the loss is 1.3014228924088849 the accuracy is  0.4884
# the 32 epoch for validation data,  the loss is 1.5122990557086875 the accuracy is  0.3628
# the 33 epoch for training data,  the loss is 1.310341923318408 the accuracy is  0.4979
# the 33 epoch for validation data,  the loss is 1.52143388239648 the accuracy is  0.3642
# the 34 epoch for training data,  the loss is 1.3165551944552556 the accuracy is  0.5017
# the 34 epoch for validation data,  the loss is 1.5337125362874808 the accuracy is  0.3701
# the 35 epoch for training data,  the loss is 1.322353365996305 the accuracy is  0.5038
# the 35 epoch for validation data,  the loss is 1.5438480591802968 the accuracy is  0.3688
# the 36 epoch for training data,  the loss is 1.3138741968582532 the accuracy is  0.4991
# the 36 epoch for validation data,  the loss is 1.5374721230522086 the accuracy is  0.3675
# the 37 epoch for training data,  the loss is 1.3120580852458354 the accuracy is  0.4987
# the 37 epoch for validation data,  the loss is 1.5372307065011008 the accuracy is  0.3679
# the 38 epoch for training data,  the loss is 1.335813844234221 the accuracy is  0.5053
# the 38 epoch for validation data,  the loss is 1.5705971220744661 the accuracy is  0.3668
# the 39 epoch for training data,  the loss is 1.344845582559891 the accuracy is  0.5059
# the 39 epoch for validation data,  the loss is 1.5840433975099357 the accuracy is  0.372
# the last model is in 39 the accuracy is 0.372
# the loss is 1.5959863106144982 the accuracy is  0.3707

# %%
c = one_layer_classifier(lamda=0.1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 4.973382790700071 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 4.949842483507666 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 4.076062530095694 the accuracy is  0.2423
# the 1 epoch for validation data,  the loss is 4.100148714930395 the accuracy is  0.2341
# the 2 epoch for training data,  the loss is 3.8642128189328018 the accuracy is  0.2811
# the 2 epoch for validation data,  the loss is 3.9037842680570476 the accuracy is  0.2694
# the 3 epoch for training data,  the loss is 3.721527340555889 the accuracy is  0.3071
# the 3 epoch for validation data,  the loss is 3.7730907334317987 the accuracy is  0.288
# the 4 epoch for training data,  the loss is 3.6066238341165313 the accuracy is  0.3232
# the 4 epoch for validation data,  the loss is 3.667048628779077 the accuracy is  0.3021
# the 5 epoch for training data,  the loss is 3.507863194424459 the accuracy is  0.3364
# the 5 epoch for validation data,  the loss is 3.575062734667413 the accuracy is  0.3138
# the 6 epoch for training data,  the loss is 3.414975087234846 the accuracy is  0.3483
# the 6 epoch for validation data,  the loss is 3.4888583776770705 the accuracy is  0.3231
# the 7 epoch for training data,  the loss is 3.331870897681089 the accuracy is  0.3552
# the 7 epoch for validation data,  the loss is 3.4110447114951836 the accuracy is  0.3293
# the 8 epoch for training data,  the loss is 3.2550253543753085 the accuracy is  0.3622
# the 8 epoch for validation data,  the loss is 3.3375813965713297 the accuracy is  0.3322
# the 9 epoch for training data,  the loss is 3.183175960002475 the accuracy is  0.3666
# the 9 epoch for validation data,  the loss is 3.271346775282876 the accuracy is  0.3368
# the 10 epoch for training data,  the loss is 3.1152434319107005 the accuracy is  0.3734
# the 10 epoch for validation data,  the loss is 3.2069202258662353 the accuracy is  0.3404
# the 11 epoch for training data,  the loss is 3.0504364674218 the accuracy is  0.3797
# the 11 epoch for validation data,  the loss is 3.147110622335246 the accuracy is  0.3475
# the 12 epoch for training data,  the loss is 2.9904914190973892 the accuracy is  0.3848
# the 12 epoch for validation data,  the loss is 3.089785449943225 the accuracy is  0.3487
# the 13 epoch for training data,  the loss is 2.933843499111893 the accuracy is  0.3881
# the 13 epoch for validation data,  the loss is 3.035772828183308 the accuracy is  0.3532
# the 14 epoch for training data,  the loss is 2.879919859227263 the accuracy is  0.3949
# the 14 epoch for validation data,  the loss is 2.9841615432281294 the accuracy is  0.3544
# the 15 epoch for training data,  the loss is 2.828278267645575 the accuracy is  0.3971
# the 15 epoch for validation data,  the loss is 2.9376764646111297 the accuracy is  0.3578
# the 16 epoch for training data,  the loss is 2.7789662053368622 the accuracy is  0.404
# the 16 epoch for validation data,  the loss is 2.8901881303735166 the accuracy is  0.3593
# the 17 epoch for training data,  the loss is 2.7318673375621643 the accuracy is  0.4068
# the 17 epoch for validation data,  the loss is 2.845405492928636 the accuracy is  0.3634
# the 18 epoch for training data,  the loss is 2.6884797016179336 the accuracy is  0.412
# the 18 epoch for validation data,  the loss is 2.8026217115342975 the accuracy is  0.363
# the 19 epoch for training data,  the loss is 2.6460764814996685 the accuracy is  0.4117
# the 19 epoch for validation data,  the loss is 2.763933084358424 the accuracy is  0.3633
# the 20 epoch for training data,  the loss is 2.6044766904434367 the accuracy is  0.4155
# the 20 epoch for validation data,  the loss is 2.724154733415216 the accuracy is  0.367
# the 21 epoch for training data,  the loss is 2.565787667125078 the accuracy is  0.4156
# the 21 epoch for validation data,  the loss is 2.687157798133347 the accuracy is  0.3692
# the 22 epoch for training data,  the loss is 2.529616241900425 the accuracy is  0.4223
# the 22 epoch for validation data,  the loss is 2.652009087053881 the accuracy is  0.3717
# the 23 epoch for training data,  the loss is 2.49426345133861 the accuracy is  0.4207
# the 23 epoch for validation data,  the loss is 2.618669551222831 the accuracy is  0.3718
# the 24 epoch for training data,  the loss is 2.460416802361298 the accuracy is  0.4241
# the 24 epoch for validation data,  the loss is 2.587127334899664 the accuracy is  0.3719
# the 25 epoch for training data,  the loss is 2.428915196449997 the accuracy is  0.4248
# the 25 epoch for validation data,  the loss is 2.557712651537277 the accuracy is  0.3721
# the 26 epoch for training data,  the loss is 2.399694297716473 the accuracy is  0.4249
# the 26 epoch for validation data,  the loss is 2.5288902448533364 the accuracy is  0.3714
# the 27 epoch for training data,  the loss is 2.3696448717236356 the accuracy is  0.425
# the 27 epoch for validation data,  the loss is 2.500471684411885 the accuracy is  0.3779
# the 28 epoch for training data,  the loss is 2.3401552134131625 the accuracy is  0.4304
# the 28 epoch for validation data,  the loss is 2.472879287775114 the accuracy is  0.3772
# the 29 epoch for training data,  the loss is 2.3138085855225112 the accuracy is  0.4304
# the 29 epoch for validation data,  the loss is 2.447895322684288 the accuracy is  0.3757
# the 30 epoch for training data,  the loss is 2.28814251098032 the accuracy is  0.4318
# the 30 epoch for validation data,  the loss is 2.422435962442867 the accuracy is  0.378
# the 31 epoch for training data,  the loss is 2.2632287772687074 the accuracy is  0.4333
# the 31 epoch for validation data,  the loss is 2.3978578365314274 the accuracy is  0.3807
# the 32 epoch for training data,  the loss is 2.2398183515649968 the accuracy is  0.4342
# the 32 epoch for validation data,  the loss is 2.3775688797453856 the accuracy is  0.3824
# the 33 epoch for training data,  the loss is 2.217071424908312 the accuracy is  0.4374
# the 33 epoch for validation data,  the loss is 2.3553158178992315 the accuracy is  0.379
# the 34 epoch for training data,  the loss is 2.195254022180909 the accuracy is  0.4383
# the 34 epoch for validation data,  the loss is 2.3341126722758845 the accuracy is  0.3813
# the 35 epoch for training data,  the loss is 2.1760413114093025 the accuracy is  0.4361
# the 35 epoch for validation data,  the loss is 2.3159899017041368 the accuracy is  0.3802
# the 36 epoch for training data,  the loss is 2.1552546526556493 the accuracy is  0.4395
# the 36 epoch for validation data,  the loss is 2.2967784081705673 the accuracy is  0.3832
# the 37 epoch for training data,  the loss is 2.1372593067131995 the accuracy is  0.4389
# the 37 epoch for validation data,  the loss is 2.2801206197995465 the accuracy is  0.3832
# the 38 epoch for training data,  the loss is 2.117435188421236 the accuracy is  0.4424
# the 38 epoch for validation data,  the loss is 2.2609757158052446 the accuracy is  0.3857
# the 39 epoch for training data,  the loss is 2.1003086729906992 the accuracy is  0.442
# the 39 epoch for validation data,  the loss is 2.244768468727167 the accuracy is  0.3869
# the last model is in 39 the accuracy is 0.3869
# the loss is 2.2008715457462746 the accuracy is  0.3876

# %%
c = one_layer_classifier(lamda=1, n_epochs=40, n_batch=100, eta=0.0005, decay_factor=1,svm=False)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 20.892162319888023 the accuracy is  0.0906
# the 0 epoch for validation data,  the loss is 20.91025692660189 the accuracy is  0.0891
# the 1 epoch for training data,  the loss is 24.176964642642293 the accuracy is  0.0492
# the 1 epoch for validation data,  the loss is 24.29186747776768 the accuracy is  0.0541
# the 2 epoch for training data,  the loss is 34.315064015341946 the accuracy is  0.0427
# the 2 epoch for validation data,  the loss is 34.519109501504644 the accuracy is  0.0494
# the 3 epoch for training data,  the loss is 48.238464227049555 the accuracy is  0.0449
# the 3 epoch for validation data,  the loss is 48.514353625240126 the accuracy is  0.0512
# the 4 epoch for training data,  the loss is 64.6890348987437 the accuracy is  0.047
# the 4 epoch for validation data,  the loss is 65.02913592379588 the accuracy is  0.0523
# the 5 epoch for training data,  the loss is 82.74281824699167 the accuracy is  0.0487
# the 5 epoch for validation data,  the loss is 83.14023940813578 the accuracy is  0.0529
# the 6 epoch for training data,  the loss is 101.65807095959846 the accuracy is  0.049
# the 6 epoch for validation data,  the loss is 102.10656094354191 the accuracy is  0.055
# the 7 epoch for training data,  the loss is 120.89765050280414 the accuracy is  0.051
# the 7 epoch for validation data,  the loss is 121.39158358628696 the accuracy is  0.0556
# the 8 epoch for training data,  the loss is 140.0393503435392 the accuracy is  0.0521
# the 8 epoch for validation data,  the loss is 140.57376939096906 the accuracy is  0.0564
# the 9 epoch for training data,  the loss is 158.791659915139 the accuracy is  0.0525
# the 9 epoch for validation data,  the loss is 159.36241064960237 the accuracy is  0.0564
# the 10 epoch for training data,  the loss is 176.92462489770313 the accuracy is  0.0528
# the 10 epoch for validation data,  the loss is 177.5281952140618 the accuracy is  0.0566
# the 11 epoch for training data,  the loss is 194.29407688197932 the accuracy is  0.0533
# the 11 epoch for validation data,  the loss is 194.92720059443747 the accuracy is  0.0569
# the 12 epoch for training data,  the loss is 210.78742801666226 the accuracy is  0.054
# the 12 epoch for validation data,  the loss is 211.4469809832334 the accuracy is  0.0571
# the 13 epoch for training data,  the loss is 226.38730681998678 the accuracy is  0.0537
# the 13 epoch for validation data,  the loss is 227.0705305308821 the accuracy is  0.0579
# the 14 epoch for training data,  the loss is 241.0003749055174 the accuracy is  0.054
# the 14 epoch for validation data,  the loss is 241.7047566311283 the accuracy is  0.0579
# the 15 epoch for training data,  the loss is 254.6670493962322 the accuracy is  0.0543
# the 15 epoch for validation data,  the loss is 255.3902582582015 the accuracy is  0.0584
# the 16 epoch for training data,  the loss is 267.3808665109203 the accuracy is  0.0549
# the 16 epoch for validation data,  the loss is 268.12078366761074 the accuracy is  0.0585
# the 17 epoch for training data,  the loss is 279.16204290071204 the accuracy is  0.0547
# the 17 epoch for validation data,  the loss is 279.91688848690984 the accuracy is  0.0589
# the 18 epoch for training data,  the loss is 290.06579069374453 the accuracy is  0.0548
# the 18 epoch for validation data,  the loss is 290.83388371692735 the accuracy is  0.0592
# the 19 epoch for training data,  the loss is 300.14404340771847 the accuracy is  0.0552
# the 19 epoch for validation data,  the loss is 300.9239262758446 the accuracy is  0.0589
# the 20 epoch for training data,  the loss is 309.3965513075987 the accuracy is  0.0555
# the 20 epoch for validation data,  the loss is 310.18692253560465 the accuracy is  0.0589
# the 21 epoch for training data,  the loss is 317.9059871054958 the accuracy is  0.0553
# the 21 epoch for validation data,  the loss is 318.70570690080183 the accuracy is  0.059
# the 22 epoch for training data,  the loss is 325.71023047172474 the accuracy is  0.0553
# the 22 epoch for validation data,  the loss is 326.5183687428796 the accuracy is  0.0588
# the 23 epoch for training data,  the loss is 332.8439214527147 the accuracy is  0.0552
# the 23 epoch for validation data,  the loss is 333.6595952889143 the accuracy is  0.0586
# the 24 epoch for training data,  the loss is 339.35366804059254 the accuracy is  0.0553
# the 24 epoch for validation data,  the loss is 340.1761571714001 the accuracy is  0.0587
# the 25 epoch for training data,  the loss is 345.337233398325 the accuracy is  0.0553
# the 25 epoch for validation data,  the loss is 346.1657780963811 the accuracy is  0.0585
# the 26 epoch for training data,  the loss is 350.80373695896475 the accuracy is  0.0556
# the 26 epoch for validation data,  the loss is 351.637713963974 the accuracy is  0.0584
# the 27 epoch for training data,  the loss is 355.7862530158766 the accuracy is  0.0557
# the 27 epoch for validation data,  the loss is 356.62511334790145 the accuracy is  0.0584
# the 28 epoch for training data,  the loss is 360.30927934773274 the accuracy is  0.0559
# the 28 epoch for validation data,  the loss is 361.15246511159745 the accuracy is  0.0584
# the 29 epoch for training data,  the loss is 364.4121159862966 the accuracy is  0.0561
# the 29 epoch for validation data,  the loss is 365.2592203536738 the accuracy is  0.0585
# the 30 epoch for training data,  the loss is 368.1523658233436 the accuracy is  0.0561
# the 30 epoch for validation data,  the loss is 369.0030339909498 the accuracy is  0.0584
# the 31 epoch for training data,  the loss is 371.5491468344974 the accuracy is  0.0561
# the 31 epoch for validation data,  the loss is 372.4030316278611 the accuracy is  0.0582
# the 32 epoch for training data,  the loss is 374.6345080004986 the accuracy is  0.056
# the 32 epoch for validation data,  the loss is 375.4913066977757 the accuracy is  0.0582
# the 33 epoch for training data,  the loss is 377.4182924429248 the accuracy is  0.0559
# the 33 epoch for validation data,  the loss is 378.27769372287355 the accuracy is  0.0579
# the 34 epoch for training data,  the loss is 379.98812678657305 the accuracy is  0.056
# the 34 epoch for validation data,  the loss is 380.84992157358704 the accuracy is  0.0578
# the 35 epoch for training data,  the loss is 382.3350868029756 the accuracy is  0.0558
# the 35 epoch for validation data,  the loss is 383.1990091477256 the accuracy is  0.0582
# the 36 epoch for training data,  the loss is 384.44379729979 the accuracy is  0.0558
# the 36 epoch for validation data,  the loss is 385.3096357505068 the accuracy is  0.0583
# the 37 epoch for training data,  the loss is 386.34809022013116 the accuracy is  0.0558
# the 37 epoch for validation data,  the loss is 387.2156655583286 the accuracy is  0.0581
# the 38 epoch for training data,  the loss is 388.0920070510281 the accuracy is  0.0556
# the 38 epoch for validation data,  the loss is 388.96112200332135 the accuracy is  0.0581
# the 39 epoch for training data,  the loss is 389.6690644441871 the accuracy is  0.0556
# the 39 epoch for validation data,  the loss is 390.53952112071477 the accuracy is  0.0582
# the last model is in 39 the accuracy is 0.0582
# the loss is 390.97578673622763 the accuracy is  0.0568

# %%
c = one_layer_classifier(lamda=0.1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=True)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 14.751546849957414 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 14.715373656224802 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 8.393188073591466 the accuracy is  0.3047
# the 1 epoch for validation data,  the loss is 8.868094271329477 the accuracy is  0.2847
# the 2 epoch for training data,  the loss is 7.749358099070735 the accuracy is  0.3384
# the 2 epoch for validation data,  the loss is 8.396817147801212 the accuracy is  0.3132
# the 3 epoch for training data,  the loss is 7.373446086656347 the accuracy is  0.3653
# the 3 epoch for validation data,  the loss is 8.147584454758606 the accuracy is  0.3289
# the 4 epoch for training data,  the loss is 7.196792360779071 the accuracy is  0.3742
# the 4 epoch for validation data,  the loss is 8.026408862846626 the accuracy is  0.3313
# the 5 epoch for training data,  the loss is 7.021196138454236 the accuracy is  0.3908
# the 5 epoch for validation data,  the loss is 7.930346277647178 the accuracy is  0.3435
# the 6 epoch for training data,  the loss is 6.888136466161994 the accuracy is  0.39
# the 6 epoch for validation data,  the loss is 7.875007052513496 the accuracy is  0.3312
# the 7 epoch for training data,  the loss is 6.83141329809315 the accuracy is  0.3948
# the 7 epoch for validation data,  the loss is 7.896377356435709 the accuracy is  0.3371
# the 8 epoch for training data,  the loss is 6.62521556153225 the accuracy is  0.4075
# the 8 epoch for validation data,  the loss is 7.7432536995765355 the accuracy is  0.3415
# the 9 epoch for training data,  the loss is 6.475342536845188 the accuracy is  0.4238
# the 9 epoch for validation data,  the loss is 7.621302770537092 the accuracy is  0.3515
# the 10 epoch for training data,  the loss is 6.453145213648349 the accuracy is  0.4135
# the 10 epoch for validation data,  the loss is 7.628653648628792 the accuracy is  0.3437
# the 11 epoch for training data,  the loss is 6.32816065626227 the accuracy is  0.4181
# the 11 epoch for validation data,  the loss is 7.57066670094269 the accuracy is  0.3461
# the 12 epoch for training data,  the loss is 6.287211940740984 the accuracy is  0.4259
# the 12 epoch for validation data,  the loss is 7.53561568423053 the accuracy is  0.3465
# the 13 epoch for training data,  the loss is 6.227131359849282 the accuracy is  0.4263
# the 13 epoch for validation data,  the loss is 7.512224659573039 the accuracy is  0.35
# the 14 epoch for training data,  the loss is 6.1950625695693144 the accuracy is  0.4233
# the 14 epoch for validation data,  the loss is 7.500785969069732 the accuracy is  0.3455
# the 15 epoch for training data,  the loss is 6.084449618257041 the accuracy is  0.4436
# the 15 epoch for validation data,  the loss is 7.450157617811242 the accuracy is  0.3531
# the 16 epoch for training data,  the loss is 6.038654605056042 the accuracy is  0.4349
# the 16 epoch for validation data,  the loss is 7.435645381688971 the accuracy is  0.3423
# the 17 epoch for training data,  the loss is 5.944888494610757 the accuracy is  0.4399
# the 17 epoch for validation data,  the loss is 7.371049633864562 the accuracy is  0.3458
# the 18 epoch for training data,  the loss is 5.977548061881505 the accuracy is  0.4368
# the 18 epoch for validation data,  the loss is 7.41899258674872 the accuracy is  0.3458
# the 19 epoch for training data,  the loss is 5.866927543398449 the accuracy is  0.443
# the 19 epoch for validation data,  the loss is 7.351447796951267 the accuracy is  0.3466
# the 20 epoch for training data,  the loss is 5.793301208317695 the accuracy is  0.4505
# the 20 epoch for validation data,  the loss is 7.283535990751788 the accuracy is  0.3482
# the 21 epoch for training data,  the loss is 5.780326307296981 the accuracy is  0.4474
# the 21 epoch for validation data,  the loss is 7.293129344511626 the accuracy is  0.3513
# the 22 epoch for training data,  the loss is 5.766005560588813 the accuracy is  0.454
# the 22 epoch for validation data,  the loss is 7.26133114097524 the accuracy is  0.3527
# the 23 epoch for training data,  the loss is 5.686252649862101 the accuracy is  0.453
# the 23 epoch for validation data,  the loss is 7.215813064055354 the accuracy is  0.3507
# the 24 epoch for training data,  the loss is 5.681648325790877 the accuracy is  0.4508
# the 24 epoch for validation data,  the loss is 7.252691309316549 the accuracy is  0.3531
# the 25 epoch for training data,  the loss is 5.667296938815235 the accuracy is  0.4426
# the 25 epoch for validation data,  the loss is 7.2857112896522285 the accuracy is  0.341
# the 26 epoch for training data,  the loss is 5.55959179425853 the accuracy is  0.4599
# the 26 epoch for validation data,  the loss is 7.172972478497691 the accuracy is  0.3541
# the 27 epoch for training data,  the loss is 5.563033135187827 the accuracy is  0.4613
# the 27 epoch for validation data,  the loss is 7.191610339161949 the accuracy is  0.3555
# the 28 epoch for training data,  the loss is 5.47150047229192 the accuracy is  0.4668
# the 28 epoch for validation data,  the loss is 7.118776501785542 the accuracy is  0.3587
# the 29 epoch for training data,  the loss is 5.526922831940153 the accuracy is  0.4528
# the 29 epoch for validation data,  the loss is 7.179523421832383 the accuracy is  0.3454
# the 30 epoch for training data,  the loss is 5.4458888295089345 the accuracy is  0.4658
# the 30 epoch for validation data,  the loss is 7.1187602959449094 the accuracy is  0.3541
# the 31 epoch for training data,  the loss is 5.458173538004057 the accuracy is  0.4513
# the 31 epoch for validation data,  the loss is 7.135822338652785 the accuracy is  0.3449
# the 32 epoch for training data,  the loss is 5.405781488600418 the accuracy is  0.4679
# the 32 epoch for validation data,  the loss is 7.1109335598033 the accuracy is  0.3565
# the 33 epoch for training data,  the loss is 5.410860906192221 the accuracy is  0.4613
# the 33 epoch for validation data,  the loss is 7.121823056342964 the accuracy is  0.3442
# the 34 epoch for training data,  the loss is 5.374626320505408 the accuracy is  0.4643
# the 34 epoch for validation data,  the loss is 7.089167049876702 the accuracy is  0.3548
# the 35 epoch for training data,  the loss is 5.3486941004801425 the accuracy is  0.4652
# the 35 epoch for validation data,  the loss is 7.10794165012863 the accuracy is  0.3487
# the 36 epoch for training data,  the loss is 5.2910312416076675 the accuracy is  0.4751
# the 36 epoch for validation data,  the loss is 7.026633344106222 the accuracy is  0.3542
# the 37 epoch for training data,  the loss is 5.286339489788194 the accuracy is  0.474
# the 37 epoch for validation data,  the loss is 7.021223076461025 the accuracy is  0.3622
# the 38 epoch for training data,  the loss is 5.232603805835006 the accuracy is  0.4755
# the 38 epoch for validation data,  the loss is 7.016993817830986 the accuracy is  0.3526
# the 39 epoch for training data,  the loss is 5.2187953404751575 the accuracy is  0.4767
# the 39 epoch for validation data,  the loss is 7.034004859729142 the accuracy is  0.3604
# the last model is in 39 the accuracy is 0.3604
# the loss is 7.008057398981481 the accuracy is  0.3519

# %%
c = one_layer_classifier(lamda=0.1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=True)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
# Out:
# the 0 epoch for training data,  the loss is 14.751546849957414 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 14.715373656224802 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 8.393188073591466 the accuracy is  0.3047
# the 1 epoch for validation data,  the loss is 8.868094271329477 the accuracy is  0.2847
# the 2 epoch for training data,  the loss is 7.749358099070735 the accuracy is  0.3384
# the 2 epoch for validation data,  the loss is 8.396817147801212 the accuracy is  0.3132
# the 3 epoch for training data,  the loss is 7.373446086656347 the accuracy is  0.3653
# the 3 epoch for validation data,  the loss is 8.147584454758606 the accuracy is  0.3289
# the 4 epoch for training data,  the loss is 7.196792360779071 the accuracy is  0.3742
# the 4 epoch for validation data,  the loss is 8.026408862846626 the accuracy is  0.3313
# the 5 epoch for training data,  the loss is 7.021196138454236 the accuracy is  0.3908
# the 5 epoch for validation data,  the loss is 7.930346277647178 the accuracy is  0.3435
# the 6 epoch for training data,  the loss is 6.888136466161994 the accuracy is  0.39
# the 6 epoch for validation data,  the loss is 7.875007052513496 the accuracy is  0.3312
# the 7 epoch for training data,  the loss is 6.83141329809315 the accuracy is  0.3948
# the 7 epoch for validation data,  the loss is 7.896377356435709 the accuracy is  0.3371
# the 8 epoch for training data,  the loss is 6.62521556153225 the accuracy is  0.4075
# the 8 epoch for validation data,  the loss is 7.7432536995765355 the accuracy is  0.3415
# the 9 epoch for training data,  the loss is 6.475342536845188 the accuracy is  0.4238
# the 9 epoch for validation data,  the loss is 7.621302770537092 the accuracy is  0.3515
# the 10 epoch for training data,  the loss is 6.453145213648349 the accuracy is  0.4135
# the 10 epoch for validation data,  the loss is 7.628653648628792 the accuracy is  0.3437
# the 11 epoch for training data,  the loss is 6.32816065626227 the accuracy is  0.4181
# the 11 epoch for validation data,  the loss is 7.57066670094269 the accuracy is  0.3461
# the 12 epoch for training data,  the loss is 6.287211940740984 the accuracy is  0.4259
# the 12 epoch for validation data,  the loss is 7.53561568423053 the accuracy is  0.3465
# the 13 epoch for training data,  the loss is 6.227131359849282 the accuracy is  0.4263
# the 13 epoch for validation data,  the loss is 7.512224659573039 the accuracy is  0.35
# the 14 epoch for training data,  the loss is 6.1950625695693144 the accuracy is  0.4233
# the 14 epoch for validation data,  the loss is 7.500785969069732 the accuracy is  0.3455
# the 15 epoch for training data,  the loss is 6.084449618257041 the accuracy is  0.4436
# the 15 epoch for validation data,  the loss is 7.450157617811242 the accuracy is  0.3531
# the 16 epoch for training data,  the loss is 6.038654605056042 the accuracy is  0.4349
# the 16 epoch for validation data,  the loss is 7.435645381688971 the accuracy is  0.3423
# the 17 epoch for training data,  the loss is 5.944888494610757 the accuracy is  0.4399
# the 17 epoch for validation data,  the loss is 7.371049633864562 the accuracy is  0.3458
# the 18 epoch for training data,  the loss is 5.977548061881505 the accuracy is  0.4368
# the 18 epoch for validation data,  the loss is 7.41899258674872 the accuracy is  0.3458
# the 19 epoch for training data,  the loss is 5.866927543398449 the accuracy is  0.443
# the 19 epoch for validation data,  the loss is 7.351447796951267 the accuracy is  0.3466
# the 20 epoch for training data,  the loss is 5.793301208317695 the accuracy is  0.4505
# the 20 epoch for validation data,  the loss is 7.283535990751788 the accuracy is  0.3482
# the 21 epoch for training data,  the loss is 5.780326307296981 the accuracy is  0.4474
# the 21 epoch for validation data,  the loss is 7.293129344511626 the accuracy is  0.3513
# the 22 epoch for training data,  the loss is 5.766005560588813 the accuracy is  0.454
# the 22 epoch for validation data,  the loss is 7.26133114097524 the accuracy is  0.3527
# the 23 epoch for training data,  the loss is 5.686252649862101 the accuracy is  0.453
# the 23 epoch for validation data,  the loss is 7.215813064055354 the accuracy is  0.3507
# the 24 epoch for training data,  the loss is 5.681648325790877 the accuracy is  0.4508
# the 24 epoch for validation data,  the loss is 7.252691309316549 the accuracy is  0.3531
# the 25 epoch for training data,  the loss is 5.667296938815235 the accuracy is  0.4426
# the 25 epoch for validation data,  the loss is 7.2857112896522285 the accuracy is  0.341
# the 26 epoch for training data,  the loss is 5.55959179425853 the accuracy is  0.4599
# the 26 epoch for validation data,  the loss is 7.172972478497691 the accuracy is  0.3541
# the 27 epoch for training data,  the loss is 5.563033135187827 the accuracy is  0.4613
# the 27 epoch for validation data,  the loss is 7.191610339161949 the accuracy is  0.3555
# the 28 epoch for training data,  the loss is 5.47150047229192 the accuracy is  0.4668
# the 28 epoch for validation data,  the loss is 7.118776501785542 the accuracy is  0.3587
# the 29 epoch for training data,  the loss is 5.526922831940153 the accuracy is  0.4528
# the 29 epoch for validation data,  the loss is 7.179523421832383 the accuracy is  0.3454
# the 30 epoch for training data,  the loss is 5.4458888295089345 the accuracy is  0.4658
# the 30 epoch for validation data,  the loss is 7.1187602959449094 the accuracy is  0.3541
# the 31 epoch for training data,  the loss is 5.458173538004057 the accuracy is  0.4513
# the 31 epoch for validation data,  the loss is 7.135822338652785 the accuracy is  0.3449
# the 32 epoch for training data,  the loss is 5.405781488600418 the accuracy is  0.4679
# the 32 epoch for validation data,  the loss is 7.1109335598033 the accuracy is  0.3565
# the 33 epoch for training data,  the loss is 5.410860906192221 the accuracy is  0.4613
# the 33 epoch for validation data,  the loss is 7.121823056342964 the accuracy is  0.3442
# the 34 epoch for training data,  the loss is 5.374626320505408 the accuracy is  0.4643
# the 34 epoch for validation data,  the loss is 7.089167049876702 the accuracy is  0.3548
# the 35 epoch for training data,  the loss is 5.3486941004801425 the accuracy is  0.4652
# the 35 epoch for validation data,  the loss is 7.10794165012863 the accuracy is  0.3487
# the 36 epoch for training data,  the loss is 5.2910312416076675 the accuracy is  0.4751
# the 36 epoch for validation data,  the loss is 7.026633344106222 the accuracy is  0.3542
# the 37 epoch for training data,  the loss is 5.286339489788194 the accuracy is  0.474
# the 37 epoch for validation data,  the loss is 7.021223076461025 the accuracy is  0.3622
# the 38 epoch for training data,  the loss is 5.232603805835006 the accuracy is  0.4755
# the 38 epoch for validation data,  the loss is 7.016993817830986 the accuracy is  0.3526
# the 39 epoch for training data,  the loss is 5.2187953404751575 the accuracy is  0.4767
# the 39 epoch for validation data,  the loss is 7.034004859729142 the accuracy is  0.3604
# the last model is in 39 the accuracy is 0.3604

# %%
c = one_layer_classifier(lamda=1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=True)
c.fit(Xtr, Ytr,ytr, Xva, Yva, yva)
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 32.75479037248691 the accuracy is  0.105
# the 0 epoch for validation data,  the loss is 32.7186171787543 the accuracy is  0.1189
# the 1 epoch for training data,  the loss is 22.546086894079863 the accuracy is  0.3075
# the 1 epoch for validation data,  the loss is 23.002793463997094 the accuracy is  0.2863
# the 2 epoch for training data,  the loss is 18.922268172315462 the accuracy is  0.3439
# the 2 epoch for validation data,  the loss is 19.535904867193494 the accuracy is  0.3182
# the 3 epoch for training data,  the loss is 16.163775915904267 the accuracy is  0.3764
# the 3 epoch for validation data,  the loss is 16.88149194887008 the accuracy is  0.3388
# the 4 epoch for training data,  the loss is 14.1401295547493 the accuracy is  0.3835
# the 4 epoch for validation data,  the loss is 14.89257412304161 the accuracy is  0.3391
# the 5 epoch for training data,  the loss is 12.488644954822542 the accuracy is  0.4017
# the 5 epoch for validation data,  the loss is 13.296677589447224 the accuracy is  0.3493
# the 6 epoch for training data,  the loss is 11.155316606885457 the accuracy is  0.398
# the 6 epoch for validation data,  the loss is 12.01936942392294 the accuracy is  0.3422
# the 7 epoch for training data,  the loss is 10.15938486477744 the accuracy is  0.4073
# the 7 epoch for validation data,  the loss is 11.078758258941505 the accuracy is  0.3506
# the 8 epoch for training data,  the loss is 9.193415135026962 the accuracy is  0.4146
# the 8 epoch for validation data,  the loss is 10.131884755541867 the accuracy is  0.3517
# the 9 epoch for training data,  the loss is 8.42920681654812 the accuracy is  0.4332
# the 9 epoch for validation data,  the loss is 9.361304920045942 the accuracy is  0.3658
# the 10 epoch for training data,  the loss is 7.966245323882423 the accuracy is  0.4116
# the 10 epoch for validation data,  the loss is 8.90564287088078 the accuracy is  0.3527
# the 11 epoch for training data,  the loss is 7.443521495294529 the accuracy is  0.4281
# the 11 epoch for validation data,  the loss is 8.427977503774562 the accuracy is  0.3635
# the 12 epoch for training data,  the loss is 7.12870331215283 the accuracy is  0.4221
# the 12 epoch for validation data,  the loss is 8.111366860918604 the accuracy is  0.3527
# the 13 epoch for training data,  the loss is 6.81955233005492 the accuracy is  0.4265
# the 13 epoch for validation data,  the loss is 7.803120007934584 the accuracy is  0.3604
# the 14 epoch for training data,  the loss is 6.630880957845645 the accuracy is  0.4247
# the 14 epoch for validation data,  the loss is 7.610761099238696 the accuracy is  0.3553
# the 15 epoch for training data,  the loss is 6.350522155013829 the accuracy is  0.44
# the 15 epoch for validation data,  the loss is 7.379518119213225 the accuracy is  0.3654
# the 16 epoch for training data,  the loss is 6.215184744139821 the accuracy is  0.4288
# the 16 epoch for validation data,  the loss is 7.249984766722918 the accuracy is  0.3551
# the 17 epoch for training data,  the loss is 6.025244721195312 the accuracy is  0.4374
# the 17 epoch for validation data,  the loss is 7.060588339169136 the accuracy is  0.3622
# the 18 epoch for training data,  the loss is 6.0447203656680655 the accuracy is  0.4242
# the 18 epoch for validation data,  the loss is 7.086071869648798 the accuracy is  0.3526
# the 19 epoch for training data,  the loss is 5.842631405311189 the accuracy is  0.4312
# the 19 epoch for validation data,  the loss is 6.915546760726371 the accuracy is  0.3552
# the 20 epoch for training data,  the loss is 5.749862990487074 the accuracy is  0.441
# the 20 epoch for validation data,  the loss is 6.790428603799928 the accuracy is  0.3638
# the 21 epoch for training data,  the loss is 5.754895763893427 the accuracy is  0.4323
# the 21 epoch for validation data,  the loss is 6.813090279101713 the accuracy is  0.3561
# the 22 epoch for training data,  the loss is 5.718749462330773 the accuracy is  0.4398
# the 22 epoch for validation data,  the loss is 6.727547969934507 the accuracy is  0.3654
# the 23 epoch for training data,  the loss is 5.647725102806563 the accuracy is  0.4328
# the 23 epoch for validation data,  the loss is 6.690260292238968 the accuracy is  0.3623
# the 24 epoch for training data,  the loss is 5.657674722086683 the accuracy is  0.4283
# the 24 epoch for validation data,  the loss is 6.726565155118028 the accuracy is  0.3574
# the 25 epoch for training data,  the loss is 5.618177833042942 the accuracy is  0.4273
# the 25 epoch for validation data,  the loss is 6.721639015177779 the accuracy is  0.3471
# the 26 epoch for training data,  the loss is 5.551320078302338 the accuracy is  0.4446
# the 26 epoch for validation data,  the loss is 6.615781036621708 the accuracy is  0.3648
# the 27 epoch for training data,  the loss is 5.57339797364384 the accuracy is  0.4449
# the 27 epoch for validation data,  the loss is 6.644737766924173 the accuracy is  0.3662
# the 28 epoch for training data,  the loss is 5.492027370276644 the accuracy is  0.4412
# the 28 epoch for validation data,  the loss is 6.569595498997629 the accuracy is  0.3727
# the 29 epoch for training data,  the loss is 5.565809599527099 the accuracy is  0.4276
# the 29 epoch for validation data,  the loss is 6.62236314038408 the accuracy is  0.3509
# the 30 epoch for training data,  the loss is 5.48785848215412 the accuracy is  0.4425
# the 30 epoch for validation data,  the loss is 6.551123588725586 the accuracy is  0.3693
# the 31 epoch for training data,  the loss is 5.525051019945473 the accuracy is  0.4287
# the 31 epoch for validation data,  the loss is 6.573412168732846 the accuracy is  0.3605
# the 32 epoch for training data,  the loss is 5.552525078736461 the accuracy is  0.4318
# the 32 epoch for validation data,  the loss is 6.6270881867767715 the accuracy is  0.3595
# the 33 epoch for training data,  the loss is 5.525762691681226 the accuracy is  0.4322
# the 33 epoch for validation data,  the loss is 6.597174094706672 the accuracy is  0.3501
# the 34 epoch for training data,  the loss is 5.492744693840429 the accuracy is  0.4357
# the 34 epoch for validation data,  the loss is 6.563469744854953 the accuracy is  0.3642
# the 35 epoch for training data,  the loss is 5.542147633933801 the accuracy is  0.4329
# the 35 epoch for validation data,  the loss is 6.625970097846707 the accuracy is  0.3583
# the 36 epoch for training data,  the loss is 5.516511992090931 the accuracy is  0.4342
# the 36 epoch for validation data,  the loss is 6.572568008829455 the accuracy is  0.3622
# the 37 epoch for training data,  the loss is 5.505391469182309 the accuracy is  0.4419
# the 37 epoch for validation data,  the loss is 6.554136531994543 the accuracy is  0.368
# the 38 epoch for training data,  the loss is 5.446102703680897 the accuracy is  0.4422
# the 38 epoch for validation data,  the loss is 6.543224540337192 the accuracy is  0.3598
# the 39 epoch for training data,  the loss is 5.459898062758778 the accuracy is  0.4497
# the 39 epoch for validation data,  the loss is 6.563929459785582 the accuracy is  0.3713
# the last model is in 39 the accuracy is 0.3713
# the loss is 6.546917857521548 the accuracy is  0.3548

# %% [markdown]
# ## Bonus part

# %% [markdown]
# ### Use all the available training data for training

# %%
Xtr1, Ytr1, ytr1 = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_1")
Xtr2, Ytr2, ytr2 = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_2")
Xtr3, Ytr3, ytr3 = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_3")
Xtr4, Ytr4, ytr4 = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_4")
Xva, Yva, yva = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/data_batch_5")
Xte, Yte, yte = load_data("D:/KTH/study/Grade1/P4/DD2424 Deep Learning in Data Science/Assignment/Datasets/test_batch")
Xtr5 = Xva[:, 1000:10000]
Ytr5 = Yva[:, 1000:10000]
ytr5 = yva[1000:10000]

# %%
print(Xtr1.shape[0],Xtr1.shape[1])
# Out:
# 3072 10000

# %%
trainX = np.concatenate((Xtr1, Xtr2, Xtr3, Xtr4, Xtr5), axis=1)
#print(trainX.shape[0], trainX.shape[1])
trainY = np.concatenate((Ytr1, Ytr2, Ytr3, Ytr4, Ytr5), axis=1)
trainy = np.concatenate((ytr1, ytr2, ytr3, ytr4, ytr5), axis=0)
#print(len(trainy))
#print(trainX.shape[1])
# Out:
# 49000
# 49000

# %%
c = one_layer_classifier(lamda=1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=1,svm=False)
c.fit(trainX, trainY,trainy, Xva[:, 0:1000], Yva[:, 0:1000], yva[0:1000])
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 22.969141449401636 the accuracy is  0.11236734693877551
# the 0 epoch for validation data,  the loss is 22.961649809571057 the accuracy is  0.113
# the 1 epoch for training data,  the loss is 15.44852139982568 the accuracy is  0.2415
# the 1 epoch for validation data,  the loss is 15.47388664457156 the accuracy is  0.237
# the 2 epoch for training data,  the loss is 10.896420094462151 the accuracy is  0.2943
# the 2 epoch for validation data,  the loss is 10.93109101832965 the accuracy is  0.286
# the 3 epoch for training data,  the loss is 7.895171381730488 the accuracy is  0.3217
# the 3 epoch for validation data,  the loss is 7.937310422273436 the accuracy is  0.313
# the 4 epoch for training data,  the loss is 5.899949683672051 the accuracy is  0.3448
# the 4 epoch for validation data,  the loss is 5.944671697364298 the accuracy is  0.334
# the 5 epoch for training data,  the loss is 4.571819436398213 the accuracy is  0.3602
# the 5 epoch for validation data,  the loss is 4.621138227467921 the accuracy is  0.349
# the 6 epoch for training data,  the loss is 3.686760749089742 the accuracy is  0.3686
# the 6 epoch for validation data,  the loss is 3.737986582228503 the accuracy is  0.363
# the 7 epoch for training data,  the loss is 3.0949435805590544 the accuracy is  0.3798
# the 7 epoch for validation data,  the loss is 3.145779812404775 the accuracy is  0.377
# the 8 epoch for training data,  the loss is 2.7012215121927867 the accuracy is  0.3847
# the 8 epoch for validation data,  the loss is 2.7524331000309994 the accuracy is  0.38
# the 9 epoch for training data,  the loss is 2.437185103254264 the accuracy is  0.3858
# the 9 epoch for validation data,  the loss is 2.490757003312854 the accuracy is  0.376
# the 10 epoch for training data,  the loss is 2.2612625282151644 the accuracy is  0.3862
# the 10 epoch for validation data,  the loss is 2.312011299852462 the accuracy is  0.375
# the 11 epoch for training data,  the loss is 2.1449055220228184 the accuracy is  0.3904
# the 11 epoch for validation data,  the loss is 2.199652286540225 the accuracy is  0.376
# the 12 epoch for training data,  the loss is 2.0656405204589485 the accuracy is  0.3957
# the 12 epoch for validation data,  the loss is 2.1207458121728746 the accuracy is  0.381
# the 13 epoch for training data,  the loss is 2.013305387641359 the accuracy is  0.3927
# the 13 epoch for validation data,  the loss is 2.0673575045075183 the accuracy is  0.38
# the 14 epoch for training data,  the loss is 1.9774688751842002 the accuracy is  0.3889
# the 14 epoch for validation data,  the loss is 2.02753197264744 the accuracy is  0.371
# the 15 epoch for training data,  the loss is 1.9550199094551817 the accuracy is  0.3958
# the 15 epoch for validation data,  the loss is 2.0122290341539593 the accuracy is  0.376
# the 16 epoch for training data,  the loss is 1.9383033618613001 the accuracy is  0.3952
# the 16 epoch for validation data,  the loss is 1.9895951901191586 the accuracy is  0.378
# the 17 epoch for training data,  the loss is 1.9277789984207707 the accuracy is  0.3928
# the 17 epoch for validation data,  the loss is 1.9784463585727705 the accuracy is  0.377
# the 18 epoch for training data,  the loss is 1.920763701886352 the accuracy is  0.3954
# the 18 epoch for validation data,  the loss is 1.9725832368362524 the accuracy is  0.383
# the 19 epoch for training data,  the loss is 1.9153770708612259 the accuracy is  0.3956
# the 19 epoch for validation data,  the loss is 1.9702178160107322 the accuracy is  0.38
# the 20 epoch for training data,  the loss is 1.912799762245565 the accuracy is  0.3926
# the 20 epoch for validation data,  the loss is 1.9653798838024426 the accuracy is  0.378
# the 21 epoch for training data,  the loss is 1.9098342961257067 the accuracy is  0.3965
# the 21 epoch for validation data,  the loss is 1.964394052572904 the accuracy is  0.378
# the 22 epoch for training data,  the loss is 1.9106107111745665 the accuracy is  0.3962
# the 22 epoch for validation data,  the loss is 1.9704288909286822 the accuracy is  0.379
# the 23 epoch for training data,  the loss is 1.9092021095699823 the accuracy is  0.3942
# the 23 epoch for validation data,  the loss is 1.9665174181212772 the accuracy is  0.37
# the 24 epoch for training data,  the loss is 1.9084264686884898 the accuracy is  0.3926
# the 24 epoch for validation data,  the loss is 1.9588900560455187 the accuracy is  0.375
# the 25 epoch for training data,  the loss is 1.9079522822308794 the accuracy is  0.3966
# the 25 epoch for validation data,  the loss is 1.9657253079926187 the accuracy is  0.383
# the 26 epoch for training data,  the loss is 1.9071700549723765 the accuracy is  0.3861
# the 26 epoch for validation data,  the loss is 1.9596972141964175 the accuracy is  0.37
# the 27 epoch for training data,  the loss is 1.9061963304278209 the accuracy is  0.3957
# the 27 epoch for validation data,  the loss is 1.9585465254204781 the accuracy is  0.378
# the 28 epoch for training data,  the loss is 1.9058119150202426 the accuracy is  0.3968
# the 28 epoch for validation data,  the loss is 1.9577950122478494 the accuracy is  0.372
# the 29 epoch for training data,  the loss is 1.9073071236571946 the accuracy is  0.3901
# the 29 epoch for validation data,  the loss is 1.9587091828811765 the accuracy is  0.377
# the 30 epoch for training data,  the loss is 1.9067658211968121 the accuracy is  0.39
# the 30 epoch for validation data,  the loss is 1.9595561855975254 the accuracy is  0.379
# the 31 epoch for training data,  the loss is 1.9051689456058165 the accuracy is  0.3982
# the 31 epoch for validation data,  the loss is 1.9576737322579867 the accuracy is  0.373
# the 32 epoch for training data,  the loss is 1.9054372185901323 the accuracy is  0.3927
# the 32 epoch for validation data,  the loss is 1.9604027387563854 the accuracy is  0.37
# the 33 epoch for training data,  the loss is 1.9052734258830737 the accuracy is  0.396
# the 33 epoch for validation data,  the loss is 1.960397872377259 the accuracy is  0.377
# the 34 epoch for training data,  the loss is 1.9056548077134132 the accuracy is  0.3932
# the 34 epoch for validation data,  the loss is 1.9571754014426028 the accuracy is  0.382
# the 35 epoch for training data,  the loss is 1.9052477323975874 the accuracy is  0.3972
# the 35 epoch for validation data,  the loss is 1.9603029255740527 the accuracy is  0.375
# the 36 epoch for training data,  the loss is 1.9047061341637475 the accuracy is  0.3946
# the 36 epoch for validation data,  the loss is 1.9583534280286272 the accuracy is  0.375
# the 37 epoch for training data,  the loss is 1.9061120573819736 the accuracy is  0.3914
# the 37 epoch for validation data,  the loss is 1.96045009373395 the accuracy is  0.377
# the 38 epoch for training data,  the loss is 1.9059637509827903 the accuracy is  0.3976
# the 38 epoch for validation data,  the loss is 1.9612476233759997 the accuracy is  0.376
# the 39 epoch for training data,  the loss is 1.9055450510861416 the accuracy is  0.3971
# the 39 epoch for validation data,  the loss is 1.9599314449835665 the accuracy is  0.377
# the last model is in 39 the accuracy is 0.377
# the loss is 1.937421751188373 the accuracy is  0.3736

# %% [markdown]
# ### Step Decay

# %%
c = one_layer_classifier(lamda=1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=0.95,svm=False)
c.fit(trainX, trainY,trainy, Xva[:, 0:1000], Yva[:, 0:1000], yva[0:1000])
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 22.969141449401636 the accuracy is  0.11236734693877551
# the 0 epoch for validation data,  the loss is 22.961649809571057 the accuracy is  0.113
# the 1 epoch for training data,  the loss is 15.44852139982568 the accuracy is  0.2415
# the 1 epoch for validation data,  the loss is 15.47388664457156 the accuracy is  0.237
# the 2 epoch for training data,  the loss is 11.081503404782172 the accuracy is  0.2919
# the 2 epoch for validation data,  the loss is 11.115659955839801 the accuracy is  0.282
# the 3 epoch for training data,  the loss is 8.264375177728265 the accuracy is  0.3178
# the 3 epoch for validation data,  the loss is 8.305606278843491 the accuracy is  0.309
# the 4 epoch for training data,  the loss is 6.397658413670955 the accuracy is  0.3405
# the 4 epoch for validation data,  the loss is 6.441613904681434 the accuracy is  0.326
# the 5 epoch for training data,  the loss is 5.1368588202186 the accuracy is  0.3541
# the 5 epoch for validation data,  the loss is 5.18492197097193 the accuracy is  0.338
# the 6 epoch for training data,  the loss is 4.269532299772536 the accuracy is  0.3624
# the 6 epoch for validation data,  the loss is 4.319851590754503 the accuracy is  0.362
# the 7 epoch for training data,  the loss is 3.6620277536217154 the accuracy is  0.3714
# the 7 epoch for validation data,  the loss is 3.711957369188138 the accuracy is  0.368
# the 8 epoch for training data,  the loss is 3.2309175985304197 the accuracy is  0.376
# the 8 epoch for validation data,  the loss is 3.281718110071396 the accuracy is  0.367
# the 9 epoch for training data,  the loss is 2.9198023654872727 the accuracy is  0.381
# the 9 epoch for validation data,  the loss is 2.972392918388249 the accuracy is  0.371
# the 10 epoch for training data,  the loss is 2.692266407828453 the accuracy is  0.3838
# the 10 epoch for validation data,  the loss is 2.743021242232016 the accuracy is  0.377
# the 11 epoch for training data,  the loss is 2.524216931684273 the accuracy is  0.386
# the 11 epoch for validation data,  the loss is 2.5780722347090324 the accuracy is  0.379
# the 12 epoch for training data,  the loss is 2.397232222919226 the accuracy is  0.3893
# the 12 epoch for validation data,  the loss is 2.4514432826068377 the accuracy is  0.382
# the 13 epoch for training data,  the loss is 2.3009442158315405 the accuracy is  0.3916
# the 13 epoch for validation data,  the loss is 2.35439835890541 the accuracy is  0.38
# the 14 epoch for training data,  the loss is 2.2271796352122255 the accuracy is  0.3915
# the 14 epoch for validation data,  the loss is 2.2781689290083538 the accuracy is  0.378
# the 15 epoch for training data,  the loss is 2.170179345178405 the accuracy is  0.395
# the 15 epoch for validation data,  the loss is 2.2257944689215363 the accuracy is  0.378
# the 16 epoch for training data,  the loss is 2.124819426697189 the accuracy is  0.394
# the 16 epoch for validation data,  the loss is 2.1767261254669643 the accuracy is  0.382
# the 17 epoch for training data,  the loss is 2.088995973465914 the accuracy is  0.3941
# the 17 epoch for validation data,  the loss is 2.141605111038609 the accuracy is  0.38
# the 18 epoch for training data,  the loss is 2.060686710716015 the accuracy is  0.3929
# the 18 epoch for validation data,  the loss is 2.1128567109468217 the accuracy is  0.379
# the 19 epoch for training data,  the loss is 2.037665056028435 the accuracy is  0.3957
# the 19 epoch for validation data,  the loss is 2.0912347394147393 the accuracy is  0.38
# the 20 epoch for training data,  the loss is 2.0189428366000977 the accuracy is  0.3953
# the 20 epoch for validation data,  the loss is 2.0720428891086105 the accuracy is  0.377
# the 21 epoch for training data,  the loss is 2.0035551248332664 the accuracy is  0.3967
# the 21 epoch for validation data,  the loss is 2.0572689607540315 the accuracy is  0.375
# the 22 epoch for training data,  the loss is 1.9913374439085163 the accuracy is  0.3973
# the 22 epoch for validation data,  the loss is 2.047089683941801 the accuracy is  0.379
# the 23 epoch for training data,  the loss is 1.9807507433652478 the accuracy is  0.3956
# the 23 epoch for validation data,  the loss is 2.036213556182992 the accuracy is  0.376
# the 24 epoch for training data,  the loss is 1.971888965339039 the accuracy is  0.3959
# the 24 epoch for validation data,  the loss is 2.0242596013602645 the accuracy is  0.378
# the 25 epoch for training data,  the loss is 1.964530416196249 the accuracy is  0.396
# the 25 epoch for validation data,  the loss is 2.0195812097532024 the accuracy is  0.379
# the 26 epoch for training data,  the loss is 1.958171768809031 the accuracy is  0.3954
# the 26 epoch for validation data,  the loss is 2.012152065971584 the accuracy is  0.381
# the 27 epoch for training data,  the loss is 1.9527686227061325 the accuracy is  0.3957
# the 27 epoch for validation data,  the loss is 2.0062265158852597 the accuracy is  0.377
# the 28 epoch for training data,  the loss is 1.94812192026332 the accuracy is  0.3964
# the 28 epoch for validation data,  the loss is 2.001693967420238 the accuracy is  0.375
# the 29 epoch for training data,  the loss is 1.9443090513331545 the accuracy is  0.3959
# the 29 epoch for validation data,  the loss is 1.9972279263006378 the accuracy is  0.375
# the 30 epoch for training data,  the loss is 1.9409113910340217 the accuracy is  0.3942
# the 30 epoch for validation data,  the loss is 1.9944119498819532 the accuracy is  0.383
# the 31 epoch for training data,  the loss is 1.9377974086649943 the accuracy is  0.3964
# the 31 epoch for validation data,  the loss is 1.9911377783113402 the accuracy is  0.378
# the 32 epoch for training data,  the loss is 1.935218161000427 the accuracy is  0.3961
# the 32 epoch for validation data,  the loss is 1.988951340007479 the accuracy is  0.378
# the 33 epoch for training data,  the loss is 1.9329352891464486 the accuracy is  0.3979
# the 33 epoch for validation data,  the loss is 1.9866392919891949 the accuracy is  0.377
# the 34 epoch for training data,  the loss is 1.930960076501373 the accuracy is  0.3969
# the 34 epoch for validation data,  the loss is 1.9843067742715204 the accuracy is  0.379
# the 35 epoch for training data,  the loss is 1.9291507109019768 the accuracy is  0.3974
# the 35 epoch for validation data,  the loss is 1.9831652084002647 the accuracy is  0.378
# the 36 epoch for training data,  the loss is 1.9275690706996405 the accuracy is  0.3969
# the 36 epoch for validation data,  the loss is 1.9814798156003897 the accuracy is  0.379
# the 37 epoch for training data,  the loss is 1.92620760735075 the accuracy is  0.3959
# the 37 epoch for validation data,  the loss is 1.9798214093591704 the accuracy is  0.38
# the 38 epoch for training data,  the loss is 1.9249398128663178 the accuracy is  0.3972
# the 38 epoch for validation data,  the loss is 1.9788160803554362 the accuracy is  0.379
# the 39 epoch for training data,  the loss is 1.9238062165915268 the accuracy is  0.3978
# the 39 epoch for validation data,  the loss is 1.977983906519832 the accuracy is  0.378
# the last model is in 39 the accuracy is 0.378
# the loss is 1.9541827684447282 the accuracy is  0.3751

# %% [markdown]
# ### Xavier Initialisation

# %%
c = one_layer_classifier(lamda=1, n_epochs=40, n_batch=100, eta=0.001, decay_factor=0.95,svm=False)
c.fit(trainX, trainY,trainy, Xva[:, 0:1000], Yva[:, 0:1000], yva[0:1000])
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 22.973255177115036 the accuracy is  0.111525
# the 0 epoch for validation data,  the loss is 23.0030752131383 the accuracy is  0.119
# the 1 epoch for training data,  the loss is 15.437079544304765 the accuracy is  0.2476
# the 1 epoch for validation data,  the loss is 15.487773794328215 the accuracy is  0.243
# the 2 epoch for training data,  the loss is 11.07348791057033 the accuracy is  0.2974
# the 2 epoch for validation data,  the loss is 11.12737472492298 the accuracy is  0.302
# the 3 epoch for training data,  the loss is 8.258530674426957 the accuracy is  0.322
# the 3 epoch for validation data,  the loss is 8.314893504537418 the accuracy is  0.315
# the 4 epoch for training data,  the loss is 6.392461976356843 the accuracy is  0.3434
# the 4 epoch for validation data,  the loss is 6.453206207714592 the accuracy is  0.331
# the 5 epoch for training data,  the loss is 5.131967062920263 the accuracy is  0.3562
# the 5 epoch for validation data,  the loss is 5.1920365421048125 the accuracy is  0.35
# the 6 epoch for training data,  the loss is 4.264856177096576 the accuracy is  0.366
# the 6 epoch for validation data,  the loss is 4.326525285077311 the accuracy is  0.353
# the 7 epoch for training data,  the loss is 3.6584765698584167 the accuracy is  0.3735
# the 7 epoch for validation data,  the loss is 3.7150310380263116 the accuracy is  0.363
# the 8 epoch for training data,  the loss is 3.2265566003612873 the accuracy is  0.3801
# the 8 epoch for validation data,  the loss is 3.2867317760790593 the accuracy is  0.363
# the 9 epoch for training data,  the loss is 2.9155032961745255 the accuracy is  0.384
# the 9 epoch for validation data,  the loss is 2.9755308398806855 the accuracy is  0.371
# the 10 epoch for training data,  the loss is 2.6882430296936253 the accuracy is  0.3875
# the 10 epoch for validation data,  the loss is 2.748382235900319 the accuracy is  0.38
# the 11 epoch for training data,  the loss is 2.520054848934839 the accuracy is  0.3894
# the 11 epoch for validation data,  the loss is 2.577440434809088 the accuracy is  0.376
# the 12 epoch for training data,  the loss is 2.3931470331297 the accuracy is  0.3911
# the 12 epoch for validation data,  the loss is 2.452670330828572 the accuracy is  0.379
# the 13 epoch for training data,  the loss is 2.2971860163179794 the accuracy is  0.3906
# the 13 epoch for validation data,  the loss is 2.3590467806601305 the accuracy is  0.378
# the 14 epoch for training data,  the loss is 2.2233819850117476 the accuracy is  0.392
# the 14 epoch for validation data,  the loss is 2.285305794507077 the accuracy is  0.381
# the 15 epoch for training data,  the loss is 2.1660577043851457 the accuracy is  0.3904
# the 15 epoch for validation data,  the loss is 2.2283946980759137 the accuracy is  0.377
# the 16 epoch for training data,  the loss is 2.121217244083158 the accuracy is  0.3923
# the 16 epoch for validation data,  the loss is 2.1807883258431735 the accuracy is  0.373
# the 17 epoch for training data,  the loss is 2.085576154249011 the accuracy is  0.3927
# the 17 epoch for validation data,  the loss is 2.145675699428518 the accuracy is  0.375
# the 18 epoch for training data,  the loss is 2.056940398049075 the accuracy is  0.3926
# the 18 epoch for validation data,  the loss is 2.116237919458527 the accuracy is  0.379
# the 19 epoch for training data,  the loss is 2.034048741462562 the accuracy is  0.3956
# the 19 epoch for validation data,  the loss is 2.0950777047020304 the accuracy is  0.38
# the 20 epoch for training data,  the loss is 2.015330156687252 the accuracy is  0.3946
# the 20 epoch for validation data,  the loss is 2.075526834396257 the accuracy is  0.382
# the 21 epoch for training data,  the loss is 2.000066638141568 the accuracy is  0.395
# the 21 epoch for validation data,  the loss is 2.061113102233428 the accuracy is  0.375
# the 22 epoch for training data,  the loss is 1.9876227355849576 the accuracy is  0.3943
# the 22 epoch for validation data,  the loss is 2.048187609328189 the accuracy is  0.381
# the 23 epoch for training data,  the loss is 1.9769548401344181 the accuracy is  0.3939
# the 23 epoch for validation data,  the loss is 2.036852882613787 the accuracy is  0.38
# the 24 epoch for training data,  the loss is 1.968335828795775 the accuracy is  0.394
# the 24 epoch for validation data,  the loss is 2.029372389655264 the accuracy is  0.378
# the 25 epoch for training data,  the loss is 1.9607332569136287 the accuracy is  0.3957
# the 25 epoch for validation data,  the loss is 2.0210032560219395 the accuracy is  0.383
# the 26 epoch for training data,  the loss is 1.954544713027731 the accuracy is  0.3934
# the 26 epoch for validation data,  the loss is 2.014556101972521 the accuracy is  0.379
# the 27 epoch for training data,  the loss is 1.9492820538171565 the accuracy is  0.3946
# the 27 epoch for validation data,  the loss is 2.008535419426294 the accuracy is  0.38
# the 28 epoch for training data,  the loss is 1.944606746071119 the accuracy is  0.3941
# the 28 epoch for validation data,  the loss is 2.004509416206694 the accuracy is  0.38
# the 29 epoch for training data,  the loss is 1.940678929756733 the accuracy is  0.3955
# the 29 epoch for validation data,  the loss is 2.000701134115148 the accuracy is  0.379
# the 30 epoch for training data,  the loss is 1.937312305308079 the accuracy is  0.3961
# the 30 epoch for validation data,  the loss is 1.997116219238813 the accuracy is  0.382
# the 31 epoch for training data,  the loss is 1.9342872991832498 the accuracy is  0.3959
# the 31 epoch for validation data,  the loss is 1.9942840610630441 the accuracy is  0.381
# the 32 epoch for training data,  the loss is 1.9317053375826128 the accuracy is  0.3951
# the 32 epoch for validation data,  the loss is 1.9923998908121319 the accuracy is  0.38
# the 33 epoch for training data,  the loss is 1.9294345741051449 the accuracy is  0.3952
# the 33 epoch for validation data,  the loss is 1.9895053607665794 the accuracy is  0.385
# the 34 epoch for training data,  the loss is 1.9274265485076048 the accuracy is  0.3948
# the 34 epoch for validation data,  the loss is 1.9872236235654241 the accuracy is  0.378
# the 35 epoch for training data,  the loss is 1.925632946747732 the accuracy is  0.3952
# the 35 epoch for validation data,  the loss is 1.9857363077652515 the accuracy is  0.38
# the 36 epoch for training data,  the loss is 1.924079497343745 the accuracy is  0.3959
# the 36 epoch for validation data,  the loss is 1.984282214544084 the accuracy is  0.38
# the 37 epoch for training data,  the loss is 1.9226796258116763 the accuracy is  0.3951
# the 37 epoch for validation data,  the loss is 1.9830554476547735 the accuracy is  0.382
# the 38 epoch for training data,  the loss is 1.92143598844759 the accuracy is  0.3958
# the 38 epoch for validation data,  the loss is 1.9814939757002952 the accuracy is  0.381
# the 39 epoch for training data,  the loss is 1.9203357071130245 the accuracy is  0.3958
# the 39 epoch for validation data,  the loss is 1.980214131075162 the accuracy is  0.378
# the last model is in 39 the accuracy is 0.378
# the loss is 1.9568649610520508 the accuracy is  0.3732

# %% [markdown]
# ### Increase number of epochs and decrease learning rate

# %%
c = one_layer_classifier(lamda=1, n_epochs=400, n_batch=100, eta=0.005, decay_factor=0.99,svm=False)
c.fit(trainX, trainY,trainy, Xva[:, 0:1000], Yva[:, 0:1000], yva[0:1000])
c.predict(Xte, Yte, yte)
# Out:
# the 0 epoch for training data,  the loss is 22.969141449401636 the accuracy is  0.11236734693877551
# the 0 epoch for validation data,  the loss is 23.0030752131383 the accuracy is  0.119
# the 1 epoch for training data,  the loss is 4.568705702132709 the accuracy is  0.3517
# the 1 epoch for validation data,  the loss is 4.630060201983085 the accuracy is  0.348
# the 2 epoch for training data,  the loss is 2.28254562412545 the accuracy is  0.3809
# the 2 epoch for validation data,  the loss is 2.3582772672907595 the accuracy is  0.364
# the 3 epoch for training data,  the loss is 1.9698722356790492 the accuracy is  0.3817
# the 3 epoch for validation data,  the loss is 2.0283067956991503 the accuracy is  0.362
# the 4 epoch for training data,  the loss is 1.931584277097365 the accuracy is  0.369
# the 4 epoch for validation data,  the loss is 1.9887468281228189 the accuracy is  0.348
# the 5 epoch for training data,  the loss is 1.9259431404568348 the accuracy is  0.3788
# the 5 epoch for validation data,  the loss is 1.9985300153128973 the accuracy is  0.35
# the 6 epoch for training data,  the loss is 1.9285026038178086 the accuracy is  0.3752
# the 6 epoch for validation data,  the loss is 1.9925472077424025 the accuracy is  0.359
# the 7 epoch for training data,  the loss is 1.9237288101178733 the accuracy is  0.3788
# the 7 epoch for validation data,  the loss is 1.984303856717662 the accuracy is  0.356
# the 8 epoch for training data,  the loss is 1.9308069273326067 the accuracy is  0.3802
# the 8 epoch for validation data,  the loss is 1.9964856071490307 the accuracy is  0.358
# the 9 epoch for training data,  the loss is 1.9241351559984905 the accuracy is  0.3795
# the 9 epoch for validation data,  the loss is 1.992850217142184 the accuracy is  0.372
# the 10 epoch for training data,  the loss is 1.9201044968939236 the accuracy is  0.3769
# the 10 epoch for validation data,  the loss is 1.9958779932510833 the accuracy is  0.343
# the 11 epoch for training data,  the loss is 1.9241587032174912 the accuracy is  0.3783
# the 11 epoch for validation data,  the loss is 2.0043003074992085 the accuracy is  0.346
# the 12 epoch for training data,  the loss is 1.9193178986564885 the accuracy is  0.3907
# the 12 epoch for validation data,  the loss is 1.987698479074432 the accuracy is  0.366
# the 13 epoch for training data,  the loss is 1.9262417157549085 the accuracy is  0.3679
# the 13 epoch for validation data,  the loss is 1.9988294950600707 the accuracy is  0.353
# the 14 epoch for training data,  the loss is 1.915148994177422 the accuracy is  0.38
# the 14 epoch for validation data,  the loss is 1.9786713042062274 the accuracy is  0.367
# the 15 epoch for training data,  the loss is 1.9191294569175594 the accuracy is  0.3842
# the 15 epoch for validation data,  the loss is 1.9875439461862032 the accuracy is  0.356
# the 16 epoch for training data,  the loss is 1.910596483159539 the accuracy is  0.39
# the 16 epoch for validation data,  the loss is 1.9857761902734081 the accuracy is  0.359
# the 17 epoch for training data,  the loss is 1.9196656991483363 the accuracy is  0.378
# the 17 epoch for validation data,  the loss is 1.9836227482553528 the accuracy is  0.354
# the 18 epoch for training data,  the loss is 1.9172378149926974 the accuracy is  0.3883
# the 18 epoch for validation data,  the loss is 1.985444580930925 the accuracy is  0.362
# the 19 epoch for training data,  the loss is 1.9147512114882188 the accuracy is  0.3922
# the 19 epoch for validation data,  the loss is 1.9789876066326075 the accuracy is  0.371
# the 20 epoch for training data,  the loss is 1.9180491449078951 the accuracy is  0.382
# the 20 epoch for validation data,  the loss is 1.9797709012461362 the accuracy is  0.368
# the 21 epoch for training data,  the loss is 1.91693371061611 the accuracy is  0.379
# the 21 epoch for validation data,  the loss is 1.983646759011681 the accuracy is  0.355
# the 22 epoch for training data,  the loss is 1.9219957411627757 the accuracy is  0.3842
# the 22 epoch for validation data,  the loss is 1.9899462324616135 the accuracy is  0.351
# the 23 epoch for training data,  the loss is 1.9193402236499049 the accuracy is  0.382
# the 23 epoch for validation data,  the loss is 1.9849531900379214 the accuracy is  0.362
# the 24 epoch for training data,  the loss is 1.9138749752635948 the accuracy is  0.3791
# the 24 epoch for validation data,  the loss is 1.9813779393357045 the accuracy is  0.357
# the 25 epoch for training data,  the loss is 1.912723355990108 the accuracy is  0.3897
# the 25 epoch for validation data,  the loss is 1.9740634327784314 the accuracy is  0.367
# the 26 epoch for training data,  the loss is 1.9179630857780354 the accuracy is  0.3768
# the 26 epoch for validation data,  the loss is 1.9820357952112364 the accuracy is  0.358
# the 27 epoch for training data,  the loss is 1.911994865707339 the accuracy is  0.3871
# the 27 epoch for validation data,  the loss is 1.9767473474338693 the accuracy is  0.371
# the 28 epoch for training data,  the loss is 1.9147924123586546 the accuracy is  0.3881
# the 28 epoch for validation data,  the loss is 1.9774040464676563 the accuracy is  0.368
# the 29 epoch for training data,  the loss is 1.9173967907791107 the accuracy is  0.3824
# the 29 epoch for validation data,  the loss is 1.9868127825659245 the accuracy is  0.36
# the 30 epoch for training data,  the loss is 1.9093344315336322 the accuracy is  0.3853
# the 30 epoch for validation data,  the loss is 1.9715559392735802 the accuracy is  0.36
# the 31 epoch for training data,  the loss is 1.9119518996964868 the accuracy is  0.3905
# the 31 epoch for validation data,  the loss is 1.9862937924877095 the accuracy is  0.361
# the 32 epoch for training data,  the loss is 1.912089005359116 the accuracy is  0.3865
# the 32 epoch for validation data,  the loss is 1.977193006176624 the accuracy is  0.358
# the 33 epoch for training data,  the loss is 1.9109115537046761 the accuracy is  0.3868
# the 33 epoch for validation data,  the loss is 1.9779294526457538 the accuracy is  0.364
# the 34 epoch for training data,  the loss is 1.9100065162794835 the accuracy is  0.3842
# the 34 epoch for validation data,  the loss is 1.972941990956909 the accuracy is  0.358
# the 35 epoch for training data,  the loss is 1.9097136288599876 the accuracy is  0.395
# the 35 epoch for validation data,  the loss is 1.9751514485351003 the accuracy is  0.371
# the 36 epoch for training data,  the loss is 1.9108911808844977 the accuracy is  0.3794
# the 36 epoch for validation data,  the loss is 1.9788657586492202 the accuracy is  0.361
# the 37 epoch for training data,  the loss is 1.9140276519450912 the accuracy is  0.3845
# the 37 epoch for validation data,  the loss is 1.973782920037918 the accuracy is  0.364
# the 38 epoch for training data,  the loss is 1.912415508315264 the accuracy is  0.3863
# the 38 epoch for validation data,  the loss is 1.976626869924901 the accuracy is  0.375
# the 39 epoch for training data,  the loss is 1.9100201166721442 the accuracy is  0.3887
# the 39 epoch for validation data,  the loss is 1.9734739742324607 the accuracy is  0.372
# the 40 epoch for training data,  the loss is 1.914050229025713 the accuracy is  0.3882
# the 40 epoch for validation data,  the loss is 1.9793310828831723 the accuracy is  0.346
# the 41 epoch for training data,  the loss is 1.9113260273990371 the accuracy is  0.3821
# the 41 epoch for validation data,  the loss is 1.978530860712141 the accuracy is  0.356
# the 42 epoch for training data,  the loss is 1.9128378822791638 the accuracy is  0.3861
# the 42 epoch for validation data,  the loss is 1.987407028759265 the accuracy is  0.351
# the 43 epoch for training data,  the loss is 1.9124570849098759 the accuracy is  0.3793
# the 43 epoch for validation data,  the loss is 1.972586774875016 the accuracy is  0.356
# the 44 epoch for training data,  the loss is 1.9091278353927756 the accuracy is  0.386
# the 44 epoch for validation data,  the loss is 1.9736353432415756 the accuracy is  0.362
# the 45 epoch for training data,  the loss is 1.907859004106978 the accuracy is  0.3862
# the 45 epoch for validation data,  the loss is 1.9728824801181835 the accuracy is  0.37
# the 46 epoch for training data,  the loss is 1.9156060101262298 the accuracy is  0.3766
# the 46 epoch for validation data,  the loss is 1.9773582626730841 the accuracy is  0.355
# the 47 epoch for training data,  the loss is 1.9075541021087108 the accuracy is  0.3888
# the 47 epoch for validation data,  the loss is 1.9735151213668114 the accuracy is  0.355
# the 48 epoch for training data,  the loss is 1.908211025865232 the accuracy is  0.3862
# the 48 epoch for validation data,  the loss is 1.976061753457682 the accuracy is  0.369
# the 49 epoch for training data,  the loss is 1.9144333582647313 the accuracy is  0.3818
# the 49 epoch for validation data,  the loss is 1.9787540932569412 the accuracy is  0.362
# the 50 epoch for training data,  the loss is 1.9113535695045816 the accuracy is  0.3872
# the 50 epoch for validation data,  the loss is 1.9809916109412278 the accuracy is  0.36
# the 51 epoch for training data,  the loss is 1.9116238614047607 the accuracy is  0.3815
# the 51 epoch for validation data,  the loss is 1.9757629381150426 the accuracy is  0.363
# the 52 epoch for training data,  the loss is 1.9080641807843328 the accuracy is  0.3877
# the 52 epoch for validation data,  the loss is 1.9769601133289412 the accuracy is  0.366
# the 53 epoch for training data,  the loss is 1.9060112588695173 the accuracy is  0.3982
# the 53 epoch for validation data,  the loss is 1.9709287905573019 the accuracy is  0.369
# the 54 epoch for training data,  the loss is 1.9080557188763172 the accuracy is  0.3894
# the 54 epoch for validation data,  the loss is 1.975374019491203 the accuracy is  0.355
# the 55 epoch for training data,  the loss is 1.9115148434742228 the accuracy is  0.3763
# the 55 epoch for validation data,  the loss is 1.9807467706273445 the accuracy is  0.349
# the 56 epoch for training data,  the loss is 1.9102916031661434 the accuracy is  0.3908
# the 56 epoch for validation data,  the loss is 1.9712068711058601 the accuracy is  0.366
# the 57 epoch for training data,  the loss is 1.9060178606223563 the accuracy is  0.3885
# the 57 epoch for validation data,  the loss is 1.972699663149138 the accuracy is  0.377
# the 58 epoch for training data,  the loss is 1.9080718898973885 the accuracy is  0.3939
# the 58 epoch for validation data,  the loss is 1.97582604430843 the accuracy is  0.371
# the 59 epoch for training data,  the loss is 1.912677338697864 the accuracy is  0.3836
# the 59 epoch for validation data,  the loss is 1.9848472711284009 the accuracy is  0.361
# the 60 epoch for training data,  the loss is 1.9108843153374118 the accuracy is  0.3826
# the 60 epoch for validation data,  the loss is 1.9628802565135697 the accuracy is  0.366
# the 61 epoch for training data,  the loss is 1.9085947972701847 the accuracy is  0.3806
# the 61 epoch for validation data,  the loss is 1.9772308598179753 the accuracy is  0.354
# the 62 epoch for training data,  the loss is 1.9043787059272677 the accuracy is  0.3942
# the 62 epoch for validation data,  the loss is 1.963342567930456 the accuracy is  0.378
# the 63 epoch for training data,  the loss is 1.9046877121284618 the accuracy is  0.3951
# the 63 epoch for validation data,  the loss is 1.9686714447286235 the accuracy is  0.373
# the 64 epoch for training data,  the loss is 1.9060377223779381 the accuracy is  0.3868
# the 64 epoch for validation data,  the loss is 1.9733242865185716 the accuracy is  0.367
# the 65 epoch for training data,  the loss is 1.904577801653708 the accuracy is  0.3959
# the 65 epoch for validation data,  the loss is 1.9735381575747606 the accuracy is  0.375
# the 66 epoch for training data,  the loss is 1.9058101861274461 the accuracy is  0.3925
# the 66 epoch for validation data,  the loss is 1.970111765309766 the accuracy is  0.36
# the 67 epoch for training data,  the loss is 1.9123229437654359 the accuracy is  0.3848
# the 67 epoch for validation data,  the loss is 1.9819759852641916 the accuracy is  0.35
# the 68 epoch for training data,  the loss is 1.9076167944911284 the accuracy is  0.3893
# the 68 epoch for validation data,  the loss is 1.973109121489502 the accuracy is  0.367
# the 69 epoch for training data,  the loss is 1.9118539529404392 the accuracy is  0.3858
# the 69 epoch for validation data,  the loss is 1.9722393159182205 the accuracy is  0.356
# the 70 epoch for training data,  the loss is 1.9062546094245807 the accuracy is  0.3942
# the 70 epoch for validation data,  the loss is 1.9645475815778308 the accuracy is  0.372
# the 71 epoch for training data,  the loss is 1.9090807614589567 the accuracy is  0.3871
# the 71 epoch for validation data,  the loss is 1.9729099578290632 the accuracy is  0.35
# the 72 epoch for training data,  the loss is 1.9054220297861266 the accuracy is  0.3924
# the 72 epoch for validation data,  the loss is 1.9701424735818591 the accuracy is  0.373
# the 73 epoch for training data,  the loss is 1.90394810141943 the accuracy is  0.3926
# the 73 epoch for validation data,  the loss is 1.9705857889829927 the accuracy is  0.375
# the 74 epoch for training data,  the loss is 1.9058044190237107 the accuracy is  0.393
# the 74 epoch for validation data,  the loss is 1.9655835645259208 the accuracy is  0.355
# the 75 epoch for training data,  the loss is 1.9088551724247047 the accuracy is  0.3917
# the 75 epoch for validation data,  the loss is 1.9696936036370836 the accuracy is  0.359
# the 76 epoch for training data,  the loss is 1.9082774439036063 the accuracy is  0.3852
# the 76 epoch for validation data,  the loss is 1.9749443408922793 the accuracy is  0.356
# the 77 epoch for training data,  the loss is 1.906774413800929 the accuracy is  0.3933
# the 77 epoch for validation data,  the loss is 1.968687222068634 the accuracy is  0.368
# the 78 epoch for training data,  the loss is 1.9032583036603807 the accuracy is  0.3952
# the 78 epoch for validation data,  the loss is 1.9669299723891736 the accuracy is  0.384
# the 79 epoch for training data,  the loss is 1.9057750877982582 the accuracy is  0.3881
# the 79 epoch for validation data,  the loss is 1.975623683794696 the accuracy is  0.35
# the 80 epoch for training data,  the loss is 1.9066494204415059 the accuracy is  0.3945
# the 80 epoch for validation data,  the loss is 1.9701692816242236 the accuracy is  0.366
# the 81 epoch for training data,  the loss is 1.9039334876022347 the accuracy is  0.3912
# the 81 epoch for validation data,  the loss is 1.9718053405388556 the accuracy is  0.379
# the 82 epoch for training data,  the loss is 1.9067611611699025 the accuracy is  0.391
# the 82 epoch for validation data,  the loss is 1.9801111335297965 the accuracy is  0.354
# the 83 epoch for training data,  the loss is 1.906800315612914 the accuracy is  0.3923
# the 83 epoch for validation data,  the loss is 1.9715048395679826 the accuracy is  0.375
# the 84 epoch for training data,  the loss is 1.9069292785877838 the accuracy is  0.3888
# the 84 epoch for validation data,  the loss is 1.9649537766243115 the accuracy is  0.363
# the 85 epoch for training data,  the loss is 1.9069550462704936 the accuracy is  0.3866
# the 85 epoch for validation data,  the loss is 1.970598919289057 the accuracy is  0.362
# the 86 epoch for training data,  the loss is 1.9035213557602957 the accuracy is  0.3921
# the 86 epoch for validation data,  the loss is 1.9711961550084163 the accuracy is  0.364
# the 87 epoch for training data,  the loss is 1.9058165899024517 the accuracy is  0.3877
# the 87 epoch for validation data,  the loss is 1.9740841856464624 the accuracy is  0.355
# the 88 epoch for training data,  the loss is 1.9034051407942427 the accuracy is  0.3938
# the 88 epoch for validation data,  the loss is 1.9704820339458182 the accuracy is  0.364
# the 89 epoch for training data,  the loss is 1.9055193209330261 the accuracy is  0.3982
# the 89 epoch for validation data,  the loss is 1.9711673627853894 the accuracy is  0.367
# the 90 epoch for training data,  the loss is 1.9055228062834104 the accuracy is  0.3972
# the 90 epoch for validation data,  the loss is 1.968164212437683 the accuracy is  0.358
# the 91 epoch for training data,  the loss is 1.9062745176282696 the accuracy is  0.3948
# the 91 epoch for validation data,  the loss is 1.9729337299580814 the accuracy is  0.373
# the 92 epoch for training data,  the loss is 1.9047434190396 the accuracy is  0.3918
# the 92 epoch for validation data,  the loss is 1.9644231727638637 the accuracy is  0.381
# the 93 epoch for training data,  the loss is 1.903794330090287 the accuracy is  0.3911
# the 93 epoch for validation data,  the loss is 1.9680082330513666 the accuracy is  0.37
# the 94 epoch for training data,  the loss is 1.90353794603647 the accuracy is  0.3959
# the 94 epoch for validation data,  the loss is 1.9687741823925236 the accuracy is  0.371
# the 95 epoch for training data,  the loss is 1.903512600175664 the accuracy is  0.3932
# the 95 epoch for validation data,  the loss is 1.9671869125518158 the accuracy is  0.37
# the 96 epoch for training data,  the loss is 1.903953761721284 the accuracy is  0.3982
# the 96 epoch for validation data,  the loss is 1.9728146988380153 the accuracy is  0.371
# the 97 epoch for training data,  the loss is 1.9052817076974913 the accuracy is  0.3949
# the 97 epoch for validation data,  the loss is 1.9707187348193544 the accuracy is  0.367
# the 98 epoch for training data,  the loss is 1.9039195160092315 the accuracy is  0.3937
# the 98 epoch for validation data,  the loss is 1.973972372940364 the accuracy is  0.369
# the 99 epoch for training data,  the loss is 1.9038075868677562 the accuracy is  0.3953
# the 99 epoch for validation data,  the loss is 1.9771151336826045 the accuracy is  0.359
# the 100 epoch for training data,  the loss is 1.904236204867134 the accuracy is  0.392
# the 100 epoch for validation data,  the loss is 1.9741960495589355 the accuracy is  0.354
# the 101 epoch for training data,  the loss is 1.903283825585116 the accuracy is  0.3943
# the 101 epoch for validation data,  the loss is 1.9687498972230153 the accuracy is  0.375
# the 102 epoch for training data,  the loss is 1.9029813188056748 the accuracy is  0.392
# the 102 epoch for validation data,  the loss is 1.9669997231949368 the accuracy is  0.363
# the 103 epoch for training data,  the loss is 1.903267677069167 the accuracy is  0.3946
# the 103 epoch for validation data,  the loss is 1.9696347802550305 the accuracy is  0.369
# the 104 epoch for training data,  the loss is 1.9057948752285594 the accuracy is  0.3873
# the 104 epoch for validation data,  the loss is 1.9635085471982054 the accuracy is  0.364
# the 105 epoch for training data,  the loss is 1.9025078877754888 the accuracy is  0.3979
# the 105 epoch for validation data,  the loss is 1.9705787404972608 the accuracy is  0.379
# the 106 epoch for training data,  the loss is 1.9028602464640048 the accuracy is  0.3986
# the 106 epoch for validation data,  the loss is 1.9661154746424279 the accuracy is  0.366
# the 107 epoch for training data,  the loss is 1.9028089129973518 the accuracy is  0.3975
# the 107 epoch for validation data,  the loss is 1.9712005311731404 the accuracy is  0.365
# the 108 epoch for training data,  the loss is 1.9028576345754293 the accuracy is  0.3976
# the 108 epoch for validation data,  the loss is 1.9657475868752976 the accuracy is  0.373
# the 109 epoch for training data,  the loss is 1.9038816345902185 the accuracy is  0.3878
# the 109 epoch for validation data,  the loss is 1.967027450109462 the accuracy is  0.373
# the 110 epoch for training data,  the loss is 1.9019632078873792 the accuracy is  0.3935
# the 110 epoch for validation data,  the loss is 1.9650878307481383 the accuracy is  0.368
# the 111 epoch for training data,  the loss is 1.9031719924535107 the accuracy is  0.3957
# the 111 epoch for validation data,  the loss is 1.9646713117181436 the accuracy is  0.379
# the 112 epoch for training data,  the loss is 1.905451010386707 the accuracy is  0.3913
# the 112 epoch for validation data,  the loss is 1.9714249525233158 the accuracy is  0.364
# the 113 epoch for training data,  the loss is 1.9030433017617803 the accuracy is  0.3964
# the 113 epoch for validation data,  the loss is 1.9642030708455267 the accuracy is  0.373
# the 114 epoch for training data,  the loss is 1.9033391666862458 the accuracy is  0.3924
# the 114 epoch for validation data,  the loss is 1.9667034155581198 the accuracy is  0.376
# the 115 epoch for training data,  the loss is 1.9017318903137261 the accuracy is  0.4001
# the 115 epoch for validation data,  the loss is 1.9644830439061451 the accuracy is  0.373
# the 116 epoch for training data,  the loss is 1.9032044303613098 the accuracy is  0.3868
# the 116 epoch for validation data,  the loss is 1.9649226770186505 the accuracy is  0.364
# the 117 epoch for training data,  the loss is 1.9038586966331255 the accuracy is  0.3904
# the 117 epoch for validation data,  the loss is 1.9647412686877734 the accuracy is  0.371
# the 118 epoch for training data,  the loss is 1.9018824773580292 the accuracy is  0.3963
# the 118 epoch for validation data,  the loss is 1.966452869306278 the accuracy is  0.364
# the 119 epoch for training data,  the loss is 1.9026464957533125 the accuracy is  0.3968
# the 119 epoch for validation data,  the loss is 1.9686559252014952 the accuracy is  0.368
# the 120 epoch for training data,  the loss is 1.9025220326220644 the accuracy is  0.3968
# the 120 epoch for validation data,  the loss is 1.9670813020336722 the accuracy is  0.366
# the 121 epoch for training data,  the loss is 1.9024046606427152 the accuracy is  0.3957
# the 121 epoch for validation data,  the loss is 1.9734362383909232 the accuracy is  0.369
# the 122 epoch for training data,  the loss is 1.902506412888318 the accuracy is  0.3935
# the 122 epoch for validation data,  the loss is 1.9691357849491662 the accuracy is  0.374
# the 123 epoch for training data,  the loss is 1.9034571775422275 the accuracy is  0.3939
# the 123 epoch for validation data,  the loss is 1.9726265184837877 the accuracy is  0.369
# the 124 epoch for training data,  the loss is 1.902736258571868 the accuracy is  0.3939
# the 124 epoch for validation data,  the loss is 1.9669588461616265 the accuracy is  0.367
# the 125 epoch for training data,  the loss is 1.900552936568083 the accuracy is  0.3991
# the 125 epoch for validation data,  the loss is 1.9635365849770656 the accuracy is  0.374
# the 126 epoch for training data,  the loss is 1.904175104837022 the accuracy is  0.3908
# the 126 epoch for validation data,  the loss is 1.9686606052780429 the accuracy is  0.364
# the 127 epoch for training data,  the loss is 1.9041261616860319 the accuracy is  0.3938
# the 127 epoch for validation data,  the loss is 1.9686678470434855 the accuracy is  0.371
# the 128 epoch for training data,  the loss is 1.9012363558576135 the accuracy is  0.3986
# the 128 epoch for validation data,  the loss is 1.9640044290606193 the accuracy is  0.379
# the 129 epoch for training data,  the loss is 1.900891179804903 the accuracy is  0.3999
# the 129 epoch for validation data,  the loss is 1.9661309708510406 the accuracy is  0.373
# the 130 epoch for training data,  the loss is 1.9030229424727971 the accuracy is  0.3929
# the 130 epoch for validation data,  the loss is 1.9655802235130624 the accuracy is  0.368
# the 131 epoch for training data,  the loss is 1.9017286485111786 the accuracy is  0.3955
# the 131 epoch for validation data,  the loss is 1.9705278105372341 the accuracy is  0.368
# the 132 epoch for training data,  the loss is 1.9025242588095805 the accuracy is  0.3939
# the 132 epoch for validation data,  the loss is 1.967790878273354 the accuracy is  0.378
# the 133 epoch for training data,  the loss is 1.9008452560164188 the accuracy is  0.3988
# the 133 epoch for validation data,  the loss is 1.9602762307214585 the accuracy is  0.375
# the 134 epoch for training data,  the loss is 1.9028603818720558 the accuracy is  0.3986
# the 134 epoch for validation data,  the loss is 1.9640156457986317 the accuracy is  0.373
# the 135 epoch for training data,  the loss is 1.900180311116781 the accuracy is  0.3986
# the 135 epoch for validation data,  the loss is 1.9666393989540856 the accuracy is  0.372
# the 136 epoch for training data,  the loss is 1.9043414266648053 the accuracy is  0.3871
# the 136 epoch for validation data,  the loss is 1.9726064867325699 the accuracy is  0.368
# the 137 epoch for training data,  the loss is 1.9014202496749988 the accuracy is  0.3998
# the 137 epoch for validation data,  the loss is 1.9649585586719363 the accuracy is  0.362
# the 138 epoch for training data,  the loss is 1.900822405262156 the accuracy is  0.3945
# the 138 epoch for validation data,  the loss is 1.9660208354315982 the accuracy is  0.369
# the 139 epoch for training data,  the loss is 1.9022866116069506 the accuracy is  0.3945
# the 139 epoch for validation data,  the loss is 1.970549767754087 the accuracy is  0.369
# the 140 epoch for training data,  the loss is 1.901354645277896 the accuracy is  0.3895
# the 140 epoch for validation data,  the loss is 1.966206174161353 the accuracy is  0.369
# the 141 epoch for training data,  the loss is 1.901848609871939 the accuracy is  0.3945
# the 141 epoch for validation data,  the loss is 1.9681712727175937 the accuracy is  0.366
# the 142 epoch for training data,  the loss is 1.9011185323274418 the accuracy is  0.3977
# the 142 epoch for validation data,  the loss is 1.9681288905311434 the accuracy is  0.373
# the 143 epoch for training data,  the loss is 1.9002617254202687 the accuracy is  0.3996
# the 143 epoch for validation data,  the loss is 1.964661939745821 the accuracy is  0.367
# the 144 epoch for training data,  the loss is 1.9026477974926268 the accuracy is  0.3975
# the 144 epoch for validation data,  the loss is 1.9695526706589295 the accuracy is  0.365
# the 145 epoch for training data,  the loss is 1.901115789369059 the accuracy is  0.3999
# the 145 epoch for validation data,  the loss is 1.9633737485780884 the accuracy is  0.375
# the 146 epoch for training data,  the loss is 1.9018941233568005 the accuracy is  0.3997
# the 146 epoch for validation data,  the loss is 1.9634516861601479 the accuracy is  0.375
# the 147 epoch for training data,  the loss is 1.9017431106828906 the accuracy is  0.3973
# the 147 epoch for validation data,  the loss is 1.9663767515421122 the accuracy is  0.374
# the 148 epoch for training data,  the loss is 1.9014129365121948 the accuracy is  0.3932
# the 148 epoch for validation data,  the loss is 1.9687638294870613 the accuracy is  0.365
# the 149 epoch for training data,  the loss is 1.901081614874642 the accuracy is  0.3961
# the 149 epoch for validation data,  the loss is 1.9663712118148209 the accuracy is  0.369
# the 150 epoch for training data,  the loss is 1.900887312747741 the accuracy is  0.3961
# the 150 epoch for validation data,  the loss is 1.962389829794173 the accuracy is  0.377
# the 151 epoch for training data,  the loss is 1.901153651865261 the accuracy is  0.3985
# the 151 epoch for validation data,  the loss is 1.9662410164466413 the accuracy is  0.379
# the 152 epoch for training data,  the loss is 1.900341885154052 the accuracy is  0.3999
# the 152 epoch for validation data,  the loss is 1.9652705256192613 the accuracy is  0.374
# the 153 epoch for training data,  the loss is 1.9003279492814187 the accuracy is  0.3991
# the 153 epoch for validation data,  the loss is 1.9634403360221726 the accuracy is  0.37
# the 154 epoch for training data,  the loss is 1.9015981422174852 the accuracy is  0.3942
# the 154 epoch for validation data,  the loss is 1.9646050559788102 the accuracy is  0.373
# the 155 epoch for training data,  the loss is 1.9001866780647008 the accuracy is  0.3965
# the 155 epoch for validation data,  the loss is 1.966385076342792 the accuracy is  0.373
# the 156 epoch for training data,  the loss is 1.9010186668986608 the accuracy is  0.3918
# the 156 epoch for validation data,  the loss is 1.9631662515923465 the accuracy is  0.366
# the 157 epoch for training data,  the loss is 1.9013954071602903 the accuracy is  0.3927
# the 157 epoch for validation data,  the loss is 1.9640721516097008 the accuracy is  0.369
# the 158 epoch for training data,  the loss is 1.9006218876632472 the accuracy is  0.3997
# the 158 epoch for validation data,  the loss is 1.9675392508118552 the accuracy is  0.371
# the 159 epoch for training data,  the loss is 1.8999098782780273 the accuracy is  0.3981
# the 159 epoch for validation data,  the loss is 1.9659383976714593 the accuracy is  0.378
# the 160 epoch for training data,  the loss is 1.9004508666269742 the accuracy is  0.3995
# the 160 epoch for validation data,  the loss is 1.9648639007712736 the accuracy is  0.372
# the 161 epoch for training data,  the loss is 1.9014525589458522 the accuracy is  0.3986
# the 161 epoch for validation data,  the loss is 1.9640145673047071 the accuracy is  0.378
# the 162 epoch for training data,  the loss is 1.9008437684908714 the accuracy is  0.3969
# the 162 epoch for validation data,  the loss is 1.9661237244559804 the accuracy is  0.371
# the 163 epoch for training data,  the loss is 1.8999755958532634 the accuracy is  0.3982
# the 163 epoch for validation data,  the loss is 1.9632189405224607 the accuracy is  0.374
# the 164 epoch for training data,  the loss is 1.9009963079960877 the accuracy is  0.3911
# the 164 epoch for validation data,  the loss is 1.9624855323365418 the accuracy is  0.369
# the 165 epoch for training data,  the loss is 1.9009571068434905 the accuracy is  0.3987
# the 165 epoch for validation data,  the loss is 1.9630382227723957 the accuracy is  0.372
# the 166 epoch for training data,  the loss is 1.9006816854402384 the accuracy is  0.3967
# the 166 epoch for validation data,  the loss is 1.9632143343990665 the accuracy is  0.377
# the 167 epoch for training data,  the loss is 1.901180771596908 the accuracy is  0.3983
# the 167 epoch for validation data,  the loss is 1.9670245404033728 the accuracy is  0.374
# the 168 epoch for training data,  the loss is 1.9007099095602389 the accuracy is  0.4009
# the 168 epoch for validation data,  the loss is 1.9669588676891723 the accuracy is  0.369
# the 169 epoch for training data,  the loss is 1.9008817477852542 the accuracy is  0.3994
# the 169 epoch for validation data,  the loss is 1.9643688808180109 the accuracy is  0.367
# the 170 epoch for training data,  the loss is 1.8997523053365535 the accuracy is  0.3975
# the 170 epoch for validation data,  the loss is 1.9627890769164116 the accuracy is  0.371
# the 171 epoch for training data,  the loss is 1.9001767795320914 the accuracy is  0.3992
# the 171 epoch for validation data,  the loss is 1.9648893188740788 the accuracy is  0.376
# the 172 epoch for training data,  the loss is 1.900172150679419 the accuracy is  0.4
# the 172 epoch for validation data,  the loss is 1.9644086078687466 the accuracy is  0.374
# the 173 epoch for training data,  the loss is 1.9010227446860364 the accuracy is  0.4002
# the 173 epoch for validation data,  the loss is 1.9654074941301052 the accuracy is  0.38
# the 174 epoch for training data,  the loss is 1.9001968630208999 the accuracy is  0.3997
# the 174 epoch for validation data,  the loss is 1.9631001018708463 the accuracy is  0.377
# the 175 epoch for training data,  the loss is 1.900287000740681 the accuracy is  0.401
# the 175 epoch for validation data,  the loss is 1.9661408654889472 the accuracy is  0.369
# the 176 epoch for training data,  the loss is 1.900199080893021 the accuracy is  0.3988
# the 176 epoch for validation data,  the loss is 1.9646337860162406 the accuracy is  0.372
# the 177 epoch for training data,  the loss is 1.9014852532214626 the accuracy is  0.3953
# the 177 epoch for validation data,  the loss is 1.9702487959669117 the accuracy is  0.365
# the 178 epoch for training data,  the loss is 1.900135262233616 the accuracy is  0.4025
# the 178 epoch for validation data,  the loss is 1.9629166972523306 the accuracy is  0.375
# the 179 epoch for training data,  the loss is 1.9003902096319203 the accuracy is  0.3972
# the 179 epoch for validation data,  the loss is 1.9681813233751315 the accuracy is  0.368
# the 180 epoch for training data,  the loss is 1.9002427144833351 the accuracy is  0.3984
# the 180 epoch for validation data,  the loss is 1.9641053926804632 the accuracy is  0.372
# the 181 epoch for training data,  the loss is 1.8997367249925345 the accuracy is  0.3989
# the 181 epoch for validation data,  the loss is 1.9645305067528571 the accuracy is  0.367
# the 182 epoch for training data,  the loss is 1.8999097099936744 the accuracy is  0.3996
# the 182 epoch for validation data,  the loss is 1.9651963662515823 the accuracy is  0.374
# the 183 epoch for training data,  the loss is 1.9006496196954776 the accuracy is  0.3983
# the 183 epoch for validation data,  the loss is 1.9670996372141596 the accuracy is  0.376
# the 184 epoch for training data,  the loss is 1.9002065922303917 the accuracy is  0.395
# the 184 epoch for validation data,  the loss is 1.964101115494498 the accuracy is  0.369
# the 185 epoch for training data,  the loss is 1.900154200872737 the accuracy is  0.4003
# the 185 epoch for validation data,  the loss is 1.9637900100487686 the accuracy is  0.372
# the 186 epoch for training data,  the loss is 1.9001367411815535 the accuracy is  0.3998
# the 186 epoch for validation data,  the loss is 1.963460072865428 the accuracy is  0.373
# the 187 epoch for training data,  the loss is 1.8996356475685348 the accuracy is  0.3992
# the 187 epoch for validation data,  the loss is 1.9630326422338293 the accuracy is  0.373
# the 188 epoch for training data,  the loss is 1.9001315926129545 the accuracy is  0.3959
# the 188 epoch for validation data,  the loss is 1.9642017775046543 the accuracy is  0.368
# the 189 epoch for training data,  the loss is 1.9001693833651627 the accuracy is  0.4004
# the 189 epoch for validation data,  the loss is 1.9660285313159922 the accuracy is  0.377
# the 190 epoch for training data,  the loss is 1.8998340686261328 the accuracy is  0.4001
# the 190 epoch for validation data,  the loss is 1.964893793992224 the accuracy is  0.373
# the 191 epoch for training data,  the loss is 1.9005144604676345 the accuracy is  0.3951
# the 191 epoch for validation data,  the loss is 1.9670613835927135 the accuracy is  0.373
# the 192 epoch for training data,  the loss is 1.9000446411569492 the accuracy is  0.3975
# the 192 epoch for validation data,  the loss is 1.9629200035858825 the accuracy is  0.369
# the 193 epoch for training data,  the loss is 1.8997832142004492 the accuracy is  0.3987
# the 193 epoch for validation data,  the loss is 1.9616797812462876 the accuracy is  0.375
# the 194 epoch for training data,  the loss is 1.899933064792588 the accuracy is  0.3977
# the 194 epoch for validation data,  the loss is 1.9669313500884842 the accuracy is  0.364
# the 195 epoch for training data,  the loss is 1.9000562511419192 the accuracy is  0.3968
# the 195 epoch for validation data,  the loss is 1.9676943004283232 the accuracy is  0.362
# the 196 epoch for training data,  the loss is 1.899737834256715 the accuracy is  0.4003
# the 196 epoch for validation data,  the loss is 1.9651096863963904 the accuracy is  0.376
# the 197 epoch for training data,  the loss is 1.9006008851224674 the accuracy is  0.3987
# the 197 epoch for validation data,  the loss is 1.9629477637676511 the accuracy is  0.381
# the 198 epoch for training data,  the loss is 1.8997270458710387 the accuracy is  0.3963
# the 198 epoch for validation data,  the loss is 1.9647894705096147 the accuracy is  0.37
# the 199 epoch for training data,  the loss is 1.9005174120343575 the accuracy is  0.3951
# the 199 epoch for validation data,  the loss is 1.9654382222578957 the accuracy is  0.373
# the 200 epoch for training data,  the loss is 1.9003639127527343 the accuracy is  0.3977
# the 200 epoch for validation data,  the loss is 1.9624413976704629 the accuracy is  0.366
# the 201 epoch for training data,  the loss is 1.8997773791744161 the accuracy is  0.3989
# the 201 epoch for validation data,  the loss is 1.9630001063598954 the accuracy is  0.374
# the 202 epoch for training data,  the loss is 1.8997362778085412 the accuracy is  0.397
# the 202 epoch for validation data,  the loss is 1.9658345031799285 the accuracy is  0.371
# the 203 epoch for training data,  the loss is 1.9005273729035883 the accuracy is  0.3942
# the 203 epoch for validation data,  the loss is 1.963303955333081 the accuracy is  0.37
# the 204 epoch for training data,  the loss is 1.8998579364974564 the accuracy is  0.3989
# the 204 epoch for validation data,  the loss is 1.9650027567003405 the accuracy is  0.368
# the 205 epoch for training data,  the loss is 1.900406712996106 the accuracy is  0.3962
# the 205 epoch for validation data,  the loss is 1.9625116239207703 the accuracy is  0.376
# the 206 epoch for training data,  the loss is 1.9001469540431621 the accuracy is  0.3991
# the 206 epoch for validation data,  the loss is 1.963995528540659 the accuracy is  0.375
# the 207 epoch for training data,  the loss is 1.8997280277880118 the accuracy is  0.3989
# the 207 epoch for validation data,  the loss is 1.965755375087942 the accuracy is  0.367
# the 208 epoch for training data,  the loss is 1.8994658110145533 the accuracy is  0.3992
# the 208 epoch for validation data,  the loss is 1.9636394692170691 the accuracy is  0.376
# the 209 epoch for training data,  the loss is 1.900223013561572 the accuracy is  0.401
# the 209 epoch for validation data,  the loss is 1.9635279245458344 the accuracy is  0.379
# the 210 epoch for training data,  the loss is 1.899662412300871 the accuracy is  0.3972
# the 210 epoch for validation data,  the loss is 1.9631305218855608 the accuracy is  0.371
# the 211 epoch for training data,  the loss is 1.9008677343928797 the accuracy is  0.3962
# the 211 epoch for validation data,  the loss is 1.967999096348616 the accuracy is  0.367
# the 212 epoch for training data,  the loss is 1.899296342701158 the accuracy is  0.3996
# the 212 epoch for validation data,  the loss is 1.964060013530125 the accuracy is  0.376
# the 213 epoch for training data,  the loss is 1.899568436729683 the accuracy is  0.3983
# the 213 epoch for validation data,  the loss is 1.9651483616859873 the accuracy is  0.371
# the 214 epoch for training data,  the loss is 1.8998971149814492 the accuracy is  0.3971
# the 214 epoch for validation data,  the loss is 1.9643457489565375 the accuracy is  0.374
# the 215 epoch for training data,  the loss is 1.9000225634105505 the accuracy is  0.397
# the 215 epoch for validation data,  the loss is 1.9642450871695774 the accuracy is  0.37
# the 216 epoch for training data,  the loss is 1.899612378407557 the accuracy is  0.4001
# the 216 epoch for validation data,  the loss is 1.9653205757272836 the accuracy is  0.375
# the 217 epoch for training data,  the loss is 1.8994850981387175 the accuracy is  0.3968
# the 217 epoch for validation data,  the loss is 1.9638558352213087 the accuracy is  0.368
# the 218 epoch for training data,  the loss is 1.899773336989115 the accuracy is  0.3988
# the 218 epoch for validation data,  the loss is 1.9640343694774534 the accuracy is  0.368
# the 219 epoch for training data,  the loss is 1.8999360685817361 the accuracy is  0.3952
# the 219 epoch for validation data,  the loss is 1.9622472523526011 the accuracy is  0.37
# the 220 epoch for training data,  the loss is 1.8995389811398415 the accuracy is  0.3984
# the 220 epoch for validation data,  the loss is 1.9638872690412184 the accuracy is  0.369
# the 221 epoch for training data,  the loss is 1.8994473676691053 the accuracy is  0.3988
# the 221 epoch for validation data,  the loss is 1.9627781901641652 the accuracy is  0.378
# the 222 epoch for training data,  the loss is 1.90000188140693 the accuracy is  0.3983
# the 222 epoch for validation data,  the loss is 1.9628002033352492 the accuracy is  0.369
# the 223 epoch for training data,  the loss is 1.8997448801273933 the accuracy is  0.399
# the 223 epoch for validation data,  the loss is 1.9666368833390926 the accuracy is  0.375
# the 224 epoch for training data,  the loss is 1.8995714699049728 the accuracy is  0.4001
# the 224 epoch for validation data,  the loss is 1.963204867203513 the accuracy is  0.374
# the 225 epoch for training data,  the loss is 1.8999208579469826 the accuracy is  0.3978
# the 225 epoch for validation data,  the loss is 1.9661114238405795 the accuracy is  0.374
# the 226 epoch for training data,  the loss is 1.8997638626752131 the accuracy is  0.3984
# the 226 epoch for validation data,  the loss is 1.9616791029161824 the accuracy is  0.372
# the 227 epoch for training data,  the loss is 1.899648329978402 the accuracy is  0.3986
# the 227 epoch for validation data,  the loss is 1.9626399798176368 the accuracy is  0.382
# the 228 epoch for training data,  the loss is 1.8995891344002405 the accuracy is  0.3995
# the 228 epoch for validation data,  the loss is 1.9625798258043854 the accuracy is  0.375
# the 229 epoch for training data,  the loss is 1.899440402956285 the accuracy is  0.3986
# the 229 epoch for validation data,  the loss is 1.9628217013351417 the accuracy is  0.38
# the 230 epoch for training data,  the loss is 1.8994885415063578 the accuracy is  0.4008
# the 230 epoch for validation data,  the loss is 1.9633081798782483 the accuracy is  0.377
# the 231 epoch for training data,  the loss is 1.8998485726587175 the accuracy is  0.3989
# the 231 epoch for validation data,  the loss is 1.965384618025679 the accuracy is  0.373
# the 232 epoch for training data,  the loss is 1.8994043076852587 the accuracy is  0.3998
# the 232 epoch for validation data,  the loss is 1.9649931255772435 the accuracy is  0.372
# the 233 epoch for training data,  the loss is 1.899321025784834 the accuracy is  0.3995
# the 233 epoch for validation data,  the loss is 1.9633704152416558 the accuracy is  0.371
# the 234 epoch for training data,  the loss is 1.8997128150026668 the accuracy is  0.399
# the 234 epoch for validation data,  the loss is 1.9659862334833018 the accuracy is  0.375
# the 235 epoch for training data,  the loss is 1.8993033742983807 the accuracy is  0.4009
# the 235 epoch for validation data,  the loss is 1.9635922850815168 the accuracy is  0.38
# the 236 epoch for training data,  the loss is 1.8994967809493248 the accuracy is  0.4019
# the 236 epoch for validation data,  the loss is 1.962599871573948 the accuracy is  0.375
# the 237 epoch for training data,  the loss is 1.8992784969724643 the accuracy is  0.4003
# the 237 epoch for validation data,  the loss is 1.9641075327088169 the accuracy is  0.374
# the 238 epoch for training data,  the loss is 1.899592393076275 the accuracy is  0.3988
# the 238 epoch for validation data,  the loss is 1.9646914037888108 the accuracy is  0.371
# the 239 epoch for training data,  the loss is 1.8994733607875074 the accuracy is  0.4018
# the 239 epoch for validation data,  the loss is 1.9627551239148497 the accuracy is  0.377
# the 240 epoch for training data,  the loss is 1.8993337714633642 the accuracy is  0.397
# the 240 epoch for validation data,  the loss is 1.963869557861105 the accuracy is  0.37
# the 241 epoch for training data,  the loss is 1.899356997862288 the accuracy is  0.3997
# the 241 epoch for validation data,  the loss is 1.9649859536781258 the accuracy is  0.37
# the 242 epoch for training data,  the loss is 1.8992614479005068 the accuracy is  0.3996
# the 242 epoch for validation data,  the loss is 1.964693036495144 the accuracy is  0.374
# the 243 epoch for training data,  the loss is 1.8994648294818852 the accuracy is  0.4027
# the 243 epoch for validation data,  the loss is 1.9642927422939391 the accuracy is  0.375
# the 244 epoch for training data,  the loss is 1.8994333712610423 the accuracy is  0.3986
# the 244 epoch for validation data,  the loss is 1.9642258305041105 the accuracy is  0.368
# the 245 epoch for training data,  the loss is 1.8995271559690732 the accuracy is  0.3995
# the 245 epoch for validation data,  the loss is 1.9636528308231262 the accuracy is  0.373
# the 246 epoch for training data,  the loss is 1.8993776761939094 the accuracy is  0.3964
# the 246 epoch for validation data,  the loss is 1.9637547868005782 the accuracy is  0.374
# the 247 epoch for training data,  the loss is 1.8996177928039206 the accuracy is  0.3953
# the 247 epoch for validation data,  the loss is 1.963786752125113 the accuracy is  0.369
# the 248 epoch for training data,  the loss is 1.8994064804574018 the accuracy is  0.3971
# the 248 epoch for validation data,  the loss is 1.9646639743579064 the accuracy is  0.367
# the 249 epoch for training data,  the loss is 1.8993420419650735 the accuracy is  0.3979
# the 249 epoch for validation data,  the loss is 1.963466260272203 the accuracy is  0.37
# the 250 epoch for training data,  the loss is 1.8993628404134306 the accuracy is  0.3988
# the 250 epoch for validation data,  the loss is 1.9632195562749242 the accuracy is  0.37
# the 251 epoch for training data,  the loss is 1.8992924159668112 the accuracy is  0.3996
# the 251 epoch for validation data,  the loss is 1.9621164613036637 the accuracy is  0.381
# the 252 epoch for training data,  the loss is 1.899423153624219 the accuracy is  0.4009
# the 252 epoch for validation data,  the loss is 1.963314156569446 the accuracy is  0.374
# the 253 epoch for training data,  the loss is 1.8992530909727188 the accuracy is  0.4005
# the 253 epoch for validation data,  the loss is 1.9628577395331461 the accuracy is  0.378
# the 254 epoch for training data,  the loss is 1.8994023910725806 the accuracy is  0.3997
# the 254 epoch for validation data,  the loss is 1.9638528689254355 the accuracy is  0.377
# the 255 epoch for training data,  the loss is 1.899398610593018 the accuracy is  0.3994
# the 255 epoch for validation data,  the loss is 1.9648718461561385 the accuracy is  0.376
# the 256 epoch for training data,  the loss is 1.8996860541241367 the accuracy is  0.3996
# the 256 epoch for validation data,  the loss is 1.965940635412955 the accuracy is  0.368
# the 257 epoch for training data,  the loss is 1.8991723048602804 the accuracy is  0.4008
# the 257 epoch for validation data,  the loss is 1.9631822375488563 the accuracy is  0.374
# the 258 epoch for training data,  the loss is 1.8995586544614713 the accuracy is  0.3988
# the 258 epoch for validation data,  the loss is 1.965224824733226 the accuracy is  0.373
# the 259 epoch for training data,  the loss is 1.8991927365209293 the accuracy is  0.3998
# the 259 epoch for validation data,  the loss is 1.9641899122693451 the accuracy is  0.37
# the 260 epoch for training data,  the loss is 1.899422330957598 the accuracy is  0.3977
# the 260 epoch for validation data,  the loss is 1.9637325307517324 the accuracy is  0.373
# the 261 epoch for training data,  the loss is 1.8992112572156101 the accuracy is  0.3999
# the 261 epoch for validation data,  the loss is 1.9629718239942233 the accuracy is  0.374
# the 262 epoch for training data,  the loss is 1.8992293227885508 the accuracy is  0.3991
# the 262 epoch for validation data,  the loss is 1.9641858704439221 the accuracy is  0.371
# the 263 epoch for training data,  the loss is 1.8994210028348664 the accuracy is  0.4011
# the 263 epoch for validation data,  the loss is 1.9623311770141467 the accuracy is  0.368
# the 264 epoch for training data,  the loss is 1.899374562536679 the accuracy is  0.4001
# the 264 epoch for validation data,  the loss is 1.9621923988848764 the accuracy is  0.371
# the 265 epoch for training data,  the loss is 1.8993302602585502 the accuracy is  0.3997
# the 265 epoch for validation data,  the loss is 1.9636045202775023 the accuracy is  0.373
# the 266 epoch for training data,  the loss is 1.8993556304041923 the accuracy is  0.3994
# the 266 epoch for validation data,  the loss is 1.9642000526743963 the accuracy is  0.372
# the 267 epoch for training data,  the loss is 1.8993212977651512 the accuracy is  0.398
# the 267 epoch for validation data,  the loss is 1.9655166778656297 the accuracy is  0.368
# the 268 epoch for training data,  the loss is 1.8992210927896822 the accuracy is  0.4004
# the 268 epoch for validation data,  the loss is 1.9627289066432376 the accuracy is  0.377
# the 269 epoch for training data,  the loss is 1.899284955665097 the accuracy is  0.3995
# the 269 epoch for validation data,  the loss is 1.9629578356457318 the accuracy is  0.372
# ...
# the 311 epoch for training data,  the loss is 1.8991193135491924 the accuracy is  0.3988
# the 311 epoch for validation data,  the loss is 1.963064765909623 the accuracy is  0.373
# the 312 epoch for training data,  the loss is 1.8990929686843412 the accuracy is  0.3994
# the 312 epoch for validation data,  the loss is 1.9632187467352238 the accuracy is  0.373
# the 313 epoch for training data,  the loss is 1.8990853135351695 the accuracy is  0.3993
# the 313 epoch for validation data,  the loss is 1.9634570912926363 the accuracy is  0.375
# the 314 epoch for training data,  the loss is 1.899083633052916 the accuracy is  0.4003
# the 314 epoch for validation data,  the loss is 1.9636551808363398 the accuracy is  0.373
# the 315 epoch for training data,  the loss is 1.8991308934718967 the accuracy is  0.3995
# the 315 epoch for validation data,  the loss is 1.964236848446566 the accuracy is  0.371
# the 316 epoch for training data,  the loss is 1.899084498178239 the accuracy is  0.4007
# the 316 epoch for validation data,  the loss is 1.9635661557598716 the accuracy is  0.375
# the 317 epoch for training data,  the loss is 1.8990736682991352 the accuracy is  0.3998
# the 317 epoch for validation data,  the loss is 1.9635355075348018 the accuracy is  0.375
# the 318 epoch for training data,  the loss is 1.899066274745866 the accuracy is  0.4004
# the 318 epoch for validation data,  the loss is 1.9637383232997698 the accuracy is  0.374
# the 319 epoch for training data,  the loss is 1.8991133966308058 the accuracy is  0.4006
# the 319 epoch for validation data,  the loss is 1.9632529546829363 the accuracy is  0.374
# the 320 epoch for training data,  the loss is 1.8990582637180238 the accuracy is  0.3998
# the 320 epoch for validation data,  the loss is 1.9632362380291137 the accuracy is  0.375
# the 321 epoch for training data,  the loss is 1.8990978888681795 the accuracy is  0.4001
# the 321 epoch for validation data,  the loss is 1.9635162428424187 the accuracy is  0.374
# the 322 epoch for training data,  the loss is 1.8990690903078393 the accuracy is  0.4003
# the 322 epoch for validation data,  the loss is 1.9631422041633289 the accuracy is  0.375
# the 323 epoch for training data,  the loss is 1.899086155169115 the accuracy is  0.3987
# the 323 epoch for validation data,  the loss is 1.9631824356658605 the accuracy is  0.374
# the 324 epoch for training data,  the loss is 1.8990707001952922 the accuracy is  0.4006
# the 324 epoch for validation data,  the loss is 1.9630462823285904 the accuracy is  0.375
# the 325 epoch for training data,  the loss is 1.8991054081225724 the accuracy is  0.3995
# the 325 epoch for validation data,  the loss is 1.9630817205990496 the accuracy is  0.372
# the 326 epoch for training data,  the loss is 1.8990976274310878 the accuracy is  0.4002
# the 326 epoch for validation data,  the loss is 1.9634103506355243 the accuracy is  0.373
# the 327 epoch for training data,  the loss is 1.8990685521337725 the accuracy is  0.399
# the 327 epoch for validation data,  the loss is 1.9636855290805102 the accuracy is  0.374
# the 328 epoch for training data,  the loss is 1.8990813110826752 the accuracy is  0.4001
# the 328 epoch for validation data,  the loss is 1.963442299342854 the accuracy is  0.374
# the 329 epoch for training data,  the loss is 1.8990954824994875 the accuracy is  0.4006
# the 329 epoch for validation data,  the loss is 1.9634624133427498 the accuracy is  0.373
# the 330 epoch for training data,  the loss is 1.899166878183009 the accuracy is  0.3999
# the 330 epoch for validation data,  the loss is 1.9634197302697256 the accuracy is  0.375
# the 331 epoch for training data,  the loss is 1.8990978892667225 the accuracy is  0.4
# the 331 epoch for validation data,  the loss is 1.9632435452483792 the accuracy is  0.376
# the 332 epoch for training data,  the loss is 1.8990866034723 the accuracy is  0.4001
# the 332 epoch for validation data,  the loss is 1.963751185995582 the accuracy is  0.374
# the 333 epoch for training data,  the loss is 1.899094965210295 the accuracy is  0.3995
# the 333 epoch for validation data,  the loss is 1.9638132555736252 the accuracy is  0.373
# the 334 epoch for training data,  the loss is 1.8990880011613809 the accuracy is  0.3997
# the 334 epoch for validation data,  the loss is 1.9638371244935064 the accuracy is  0.374
# the 335 epoch for training data,  the loss is 1.8990769212602892 the accuracy is  0.3994
# the 335 epoch for validation data,  the loss is 1.9637323844206618 the accuracy is  0.373
# the 336 epoch for training data,  the loss is 1.8990756790769314 the accuracy is  0.3999
# the 336 epoch for validation data,  the loss is 1.9633825933143199 the accuracy is  0.374
# the 337 epoch for training data,  the loss is 1.8990826525529185 the accuracy is  0.3999
# the 337 epoch for validation data,  the loss is 1.9636121090892762 the accuracy is  0.375
# the 338 epoch for training data,  the loss is 1.899069069576727 the accuracy is  0.4002
# the 338 epoch for validation data,  the loss is 1.9639719855495488 the accuracy is  0.374
# the 339 epoch for training data,  the loss is 1.899119016750764 the accuracy is  0.3999
# the 339 epoch for validation data,  the loss is 1.9635372100987714 the accuracy is  0.374
# the 340 epoch for training data,  the loss is 1.8990704641044094 the accuracy is  0.4004
# the 340 epoch for validation data,  the loss is 1.9635572305612474 the accuracy is  0.374
# the 341 epoch for training data,  the loss is 1.8990670580704412 the accuracy is  0.4004
# the 341 epoch for validation data,  the loss is 1.963723454864635 the accuracy is  0.372
# the 342 epoch for training data,  the loss is 1.8990765883935143 the accuracy is  0.4002
# the 342 epoch for validation data,  the loss is 1.964027595758275 the accuracy is  0.372
# the 343 epoch for training data,  the loss is 1.8990748538014035 the accuracy is  0.4
# the 343 epoch for validation data,  the loss is 1.9636075427930226 the accuracy is  0.373
# the 344 epoch for training data,  the loss is 1.8990762394729028 the accuracy is  0.4002
# the 344 epoch for validation data,  the loss is 1.9635419656256063 the accuracy is  0.374
# the 345 epoch for training data,  the loss is 1.8990822568425603 the accuracy is  0.4001
# the 345 epoch for validation data,  the loss is 1.9631202051182541 the accuracy is  0.376
# the 346 epoch for training data,  the loss is 1.8990829590768348 the accuracy is  0.4009
# the 346 epoch for validation data,  the loss is 1.9636796262581608 the accuracy is  0.374
# the 347 epoch for training data,  the loss is 1.8990608230656936 the accuracy is  0.4007
# the 347 epoch for validation data,  the loss is 1.963456789070715 the accuracy is  0.374
# the 348 epoch for training data,  the loss is 1.899066945613876 the accuracy is  0.4001
# the 348 epoch for validation data,  the loss is 1.9640021943599193 the accuracy is  0.371
# the 349 epoch for training data,  the loss is 1.8990796410571296 the accuracy is  0.4002
# the 349 epoch for validation data,  the loss is 1.9636174664085917 the accuracy is  0.374
# the 350 epoch for training data,  the loss is 1.8990591739680467 the accuracy is  0.4003
# the 350 epoch for validation data,  the loss is 1.9635236721235474 the accuracy is  0.373
# the 351 epoch for training data,  the loss is 1.8990632576089401 the accuracy is  0.4008
# the 351 epoch for validation data,  the loss is 1.9633426233131108 the accuracy is  0.375
# the 352 epoch for training data,  the loss is 1.899057663250989 the accuracy is  0.4008
# the 352 epoch for validation data,  the loss is 1.9631693134316104 the accuracy is  0.376
# the 353 epoch for training data,  the loss is 1.8990701617266807 the accuracy is  0.4006
# the 353 epoch for validation data,  the loss is 1.9631649270021865 the accuracy is  0.375
# the 354 epoch for training data,  the loss is 1.8990601805559253 the accuracy is  0.3998
# the 354 epoch for validation data,  the loss is 1.9638133685143884 the accuracy is  0.371
# the 355 epoch for training data,  the loss is 1.8990532931997686 the accuracy is  0.4002
# the 355 epoch for validation data,  the loss is 1.9634731820326368 the accuracy is  0.373
# the 356 epoch for training data,  the loss is 1.8990426643698983 the accuracy is  0.3996
# the 356 epoch for validation data,  the loss is 1.9636073473805604 the accuracy is  0.375
# the 357 epoch for training data,  the loss is 1.899048919927872 the accuracy is  0.3995
# the 357 epoch for validation data,  the loss is 1.9633381740669111 the accuracy is  0.374
# the 358 epoch for training data,  the loss is 1.8990552006949477 the accuracy is  0.4004
# the 358 epoch for validation data,  the loss is 1.9633700772844935 the accuracy is  0.373
# the 359 epoch for training data,  the loss is 1.8990561984838878 the accuracy is  0.4005
# the 359 epoch for validation data,  the loss is 1.9635871675755128 the accuracy is  0.375
# the 360 epoch for training data,  the loss is 1.8990590066075013 the accuracy is  0.4011
# the 360 epoch for validation data,  the loss is 1.9632139810730131 the accuracy is  0.376
# the 361 epoch for training data,  the loss is 1.8990684315893718 the accuracy is  0.3993
# the 361 epoch for validation data,  the loss is 1.9638410983905765 the accuracy is  0.375
# the 362 epoch for training data,  the loss is 1.8990526366405944 the accuracy is  0.4001
# the 362 epoch for validation data,  the loss is 1.9633555551949025 the accuracy is  0.375
# the 363 epoch for training data,  the loss is 1.8990618626511044 the accuracy is  0.3996
# the 363 epoch for validation data,  the loss is 1.9633728327598896 the accuracy is  0.372
# the 364 epoch for training data,  the loss is 1.8990626726205226 the accuracy is  0.3995
# the 364 epoch for validation data,  the loss is 1.963676425169615 the accuracy is  0.374
# the 365 epoch for training data,  the loss is 1.8990663960700014 the accuracy is  0.3995
# the 365 epoch for validation data,  the loss is 1.9636421084958646 the accuracy is  0.371
# the 366 epoch for training data,  the loss is 1.8990652542514685 the accuracy is  0.3998
# the 366 epoch for validation data,  the loss is 1.9634583644798524 the accuracy is  0.374
# the 367 epoch for training data,  the loss is 1.8990550280167957 the accuracy is  0.4001
# the 367 epoch for validation data,  the loss is 1.963733567374725 the accuracy is  0.374
# the 368 epoch for training data,  the loss is 1.8990570889795368 the accuracy is  0.4001
# the 368 epoch for validation data,  the loss is 1.9638044454780557 the accuracy is  0.373
# the 369 epoch for training data,  the loss is 1.89907264662585 the accuracy is  0.3996
# the 369 epoch for validation data,  the loss is 1.9636179117179373 the accuracy is  0.372
# the 370 epoch for training data,  the loss is 1.899058620767319 the accuracy is  0.3997
# the 370 epoch for validation data,  the loss is 1.963676155710289 the accuracy is  0.374
# the 371 epoch for training data,  the loss is 1.8990547516009968 the accuracy is  0.4005
# the 371 epoch for validation data,  the loss is 1.9631200587770767 the accuracy is  0.375
# the 372 epoch for training data,  the loss is 1.899052964615066 the accuracy is  0.4004
# the 372 epoch for validation data,  the loss is 1.9634555856678633 the accuracy is  0.375
# the 373 epoch for training data,  the loss is 1.8990678357640305 the accuracy is  0.4001
# the 373 epoch for validation data,  the loss is 1.9638049564341926 the accuracy is  0.373
# the 374 epoch for training data,  the loss is 1.899044605759063 the accuracy is  0.4004
# the 374 epoch for validation data,  the loss is 1.9633548455879077 the accuracy is  0.376
# the 375 epoch for training data,  the loss is 1.8990410082739408 the accuracy is  0.4003
# the 375 epoch for validation data,  the loss is 1.9633278206501585 the accuracy is  0.374
# the 376 epoch for training data,  the loss is 1.899045765867255 the accuracy is  0.4008
# the 376 epoch for validation data,  the loss is 1.9632199833516208 the accuracy is  0.375
# the 377 epoch for training data,  the loss is 1.899042106003283 the accuracy is  0.4001
# the 377 epoch for validation data,  the loss is 1.963484028942436 the accuracy is  0.374
# the 378 epoch for training data,  the loss is 1.8990461342602887 the accuracy is  0.4006
# the 378 epoch for validation data,  the loss is 1.96313275183618 the accuracy is  0.375
# the 379 epoch for training data,  the loss is 1.8990487988417915 the accuracy is  0.4006
# the 379 epoch for validation data,  the loss is 1.963075217766966 the accuracy is  0.374
# the 380 epoch for training data,  the loss is 1.8990487264103197 the accuracy is  0.4002
# the 380 epoch for validation data,  the loss is 1.9634236733307688 the accuracy is  0.374
# the 381 epoch for training data,  the loss is 1.8990564578940354 the accuracy is  0.4007
# the 381 epoch for validation data,  the loss is 1.963217152148627 the accuracy is  0.376
# the 382 epoch for training data,  the loss is 1.8990442598566806 the accuracy is  0.4
# the 382 epoch for validation data,  the loss is 1.9633991719742736 the accuracy is  0.374
# the 383 epoch for training data,  the loss is 1.899041339311431 the accuracy is  0.3998
# the 383 epoch for validation data,  the loss is 1.9635629572930435 the accuracy is  0.374
# the 384 epoch for training data,  the loss is 1.8990492578546534 the accuracy is  0.3997
# the 384 epoch for validation data,  the loss is 1.9634558849950707 the accuracy is  0.373
# the 385 epoch for training data,  the loss is 1.8990453909548057 the accuracy is  0.3998
# the 385 epoch for validation data,  the loss is 1.963631830746568 the accuracy is  0.374
# the 386 epoch for training data,  the loss is 1.899041805779385 the accuracy is  0.4002
# the 386 epoch for validation data,  the loss is 1.9632430091274513 the accuracy is  0.376
# the 387 epoch for training data,  the loss is 1.899044827075522 the accuracy is  0.4002
# the 387 epoch for validation data,  the loss is 1.9633397427387067 the accuracy is  0.375
# the 388 epoch for training data,  the loss is 1.8990416748003458 the accuracy is  0.4003
# the 388 epoch for validation data,  the loss is 1.9635226958088934 the accuracy is  0.374
# the 389 epoch for training data,  the loss is 1.8990551523112882 the accuracy is  0.4001
# the 389 epoch for validation data,  the loss is 1.9634490076494915 the accuracy is  0.374
# the 390 epoch for training data,  the loss is 1.8990446808826618 the accuracy is  0.4004
# the 390 epoch for validation data,  the loss is 1.9635814654264305 the accuracy is  0.374
# the 391 epoch for training data,  the loss is 1.899040191084475 the accuracy is  0.3998
# the 391 epoch for validation data,  the loss is 1.9636115034260566 the accuracy is  0.374
# the 392 epoch for training data,  the loss is 1.8990431657558593 the accuracy is  0.4009
# the 392 epoch for validation data,  the loss is 1.9634655247973483 the accuracy is  0.375
# the 393 epoch for training data,  the loss is 1.8990430828063445 the accuracy is  0.4006
# the 393 epoch for validation data,  the loss is 1.9635179636167384 the accuracy is  0.374
# the 394 epoch for training data,  the loss is 1.8990493340678638 the accuracy is  0.4005
# the 394 epoch for validation data,  the loss is 1.96367197465747 the accuracy is  0.372
# the 395 epoch for training data,  the loss is 1.8990411243924992 the accuracy is  0.3997
# the 395 epoch for validation data,  the loss is 1.963454142424335 the accuracy is  0.374
# the 396 epoch for training data,  the loss is 1.899040490686839 the accuracy is  0.4001
# the 396 epoch for validation data,  the loss is 1.9634445754436376 the accuracy is  0.375
# the 397 epoch for training data,  the loss is 1.899042986768756 the accuracy is  0.4001
# the 397 epoch for validation data,  the loss is 1.9632609020450051 the accuracy is  0.375
# the 398 epoch for training data,  the loss is 1.8990462763134008 the accuracy is  0.4001
# the 398 epoch for validation data,  the loss is 1.963138252645819 the accuracy is  0.375
# the 399 epoch for training data,  the loss is 1.8990442284559945 the accuracy is  0.3999
# the 399 epoch for validation data,  the loss is 1.963335654702013 the accuracy is  0.375
# the last model is in 399 the accuracy is 0.375
# the loss is 1.9315630045686623 the accuracy is  0.382
